# %% [markdown]
# # Abstract

# %% [markdown]
# Fix columns of some SDP pools

# %% [markdown]
# # Environment

# %%
from copy import copy

# %%
from jwst.associations import AssociationPool
from jwst.associations.main import Main

# %% [markdown]
# # Library

# %%
def fix_asn_candidate(pool):
    """Fix null association candidate columns
    
    Parameters
    ----------
    pool: AssociationPool
        Pool to fix. Done in-place
    """
    for item in pool:
        obs_num = item['obs_num']
        if obs_num == 'null':
            continue
        obs_num_id = 'o{:0>3}'.format(obs_num)
        acid_str = item['asn_candidate']
        if acid_str == 'null':
            acid_str = '[]'
        acids = eval(acid_str)
        for acid_id, acid_type in acids:
            if acid_id == obs_num_id:
                break
        else:
            acids.append((obs_num_id, 'observation'))
            item['asn_candidate'] = str(acids)

# %% [markdown]
# # Main

# %% [markdown]
# ## Fix 88600 asn_candidate

# %%
jw93135 = AssociationPool.read('../data/sdp/pools/jw93135_20171108T041617_pool.csv')

# %%
jw93135['asn_candidate']
# Out:
# <Column name='asn_candidate' dtype='str25' length=196>
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
#  ...
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null

# %%
fix_asn_candidate(jw93135)

# %%
jw93135['asn_candidate']
# Out:
# <Column name='asn_candidate' dtype='str25' length=196>
# [('o327', 'observation')]
# [('o311', 'observation')]
# [('o332', 'observation')]
# [('o332', 'observation')]
# [('o337', 'observation')]
# [('o334', 'observation')]
# [('o332', 'observation')]
# [('o336', 'observation')]
# [('o335', 'observation')]
# [('o333', 'observation')]
# [('o333', 'observation')]
# [('o312', 'observation')]
#                       ...
# [('o336', 'observation')]
# [('o326', 'observation')]
# [('o324', 'observation')]
# [('o335', 'observation')]
# [('o333', 'observation')]
# [('o333', 'observation')]
# [('o325', 'observation')]
# [('o332', 'observation')]
# [('o337', 'observation')]
# [('o324', 'observation')]
# [('o337', 'observation')]
# [('o312', 'observation')]

# %%
jw93135.write('../data/sdp/pools/jw93135_20171108T041617_fixed_pool.csv', overwrite=True)

# %% [markdown]
# ## Fix 84600 asn_candidate

# %%
jw84600 = AssociationPool.read('../data/sdp/pools/jw84600_20171108T041344_pool.csv')

# %%
fix_asn_candidate(jw84600)

# %%
jw84600.write('../data/sdp/pools/jw84600_20171108T041344_fixed_pool.csv', overwrite=True)

# %%
args_dryrun = ['--dry-run', '-v', '--all-candidates']

# %%
args_nonfixed = copy(args_dryrun)
args_nonfixed.append('../data/sdp/pools/jw84600_20171108T041344_pool.csv')
results_nonfixed = Main(args_nonfixed)
# Out:
# Command-line arguments: ['--dry-run', '-v', '--all-candidates', '../data/sdp/pools/jw84600_20171108T041344_pool.csv']
# Reading pool ../data/sdp/pools/jw84600_20171108T041344_pool.csv
# Reading rules.
# Generating associations.
# There where 4 associations and 70 orphaned items found.
# Associations found are:
# jw84600-o010_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec', 'nrs_autoflat'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f100lp'}
#     opt_elem2: {'g140m'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o010\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o010_t001_nirspec_f100lp-g140m with 4 members
# jw84600-o010_spec3_002_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec', 'nrs_autoflat'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f070lp'}
#     opt_elem2: {'g140m'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o010\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o010_t001_nirspec_f070lp-g140m with 4 members
# Association jw84600-o010_image2_290_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2ImageNonScience
#         Program:      84600
#         Target:       1
#         Pool:         jw84600_20171108T041344_pool
#         Constraints:
#             single_science: {'False'}
#             non_science: {'nrs_confirm'}
#             program: {'84600'}
#             target: {'1'}
#             instrument: {'nirspec'}
#             detector: {'nrs2'}
#             opt_elem: {'f070lp'}
#             opt_elem2: {'mirror'}
#             subarray: {'full'}
#             channel: set()
#             asn_candidate: {"\\(\\'o010\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw84600010001_02101_00001_nrs2 with 1 members
# 	jw84600010001_02101_00001_nrs1 with 1 members
# 	jw84600010001_02102_00001_nrs2 with 1 members
# 	jw84600010001_02102_00001_nrs1 with 1 members
#
#
# Association jw84600-o010_spec2_292_asn
#     Parameters:
#         Product type: spec2
#         Rule:         candidate_Asn_Lv2Spec
#         Program:      84600
#         Target:       1
#         Pool:         jw84600_20171108T041344_pool
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrs_msaspec'}
#             program: {'84600'}
#             target: {'1'}
#             instrument: {'nirspec'}
#             detector: {'nrs1'}
#             opt_elem: {'f070lp'}
#             opt_elem2: {'g140m'}
#             subarray: {'full'}
#             channel: set()
#             asn_candidate: {"\\(\\'o010\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw84600010001_02101_00002_nrs1 with 1 members
# 	jw84600010001_02102_00002_nrs2 with 1 members
# 	jw84600010001_02101_00002_nrs2 with 1 members
# 	jw84600010001_02102_00002_nrs1 with 1 members

# %%
args_fixed = copy(args_dryrun)
args_fixed.append('../data/sdp/pools/jw84600_20171108T041344_fixed_pool.csv')
results_fixed = Main(args_fixed)
# Out:
# Command-line arguments: ['--dry-run', '-v', '--all-candidates', '../data/sdp/pools/jw84600_20171108T041344_fixed_pool.csv']
# Reading pool ../data/sdp/pools/jw84600_20171108T041344_fixed_pool.csv
# Reading rules.
# Generating associations.
# There where 15 associations and 8 orphaned items found.
# Associations found are:
# jw84600-o007_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_IFU
# Constraints:
#     exp_type: {'nrs_ifu'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o007\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o007_t001_nirspec_clear with 4 members
# jw84600-o040_tso3_001_asn with 1 products
# Rule=candidate_Asn_TSO_EXPTYPE
# Constraints:
#     exp_type: {'nrs_brightobj'}
#     no_tso_flag: Is Invalid
#     opt_elem: {'f070lp'}
#     opt_elem2: {'g140h'}
#     target: {'1'}
#     program: {'84600'}
#     instrument: {'nirspec'}
#     asn_candidate: {"\\(\\'o040\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o040_t001_nirspec_f070lp-g140h with 2 members
# jw84600-o008_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec', 'nrs_autoflat'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f290lp'}
#     opt_elem2: {'g395m'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o008\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o008_t001_nirspec_f290lp-g395m with 4 members
# jw84600-o010_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec', 'nrs_autoflat'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f100lp'}
#     opt_elem2: {'g140m'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o010\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o010_t001_nirspec_f100lp-g140m with 4 members
# jw84600-o012_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f170lp'}
#     opt_elem2: {'g235h'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o012\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o012_t001_nirspec_f170lp-g235h with 2 members
# jw84600-o041_tso3_001_asn with 1 products
# Rule=candidate_Asn_TSO_EXPTYPE
# Constraints:
#     exp_type: {'nrs_brightobj'}
#     no_tso_flag: Is Invalid
#     opt_elem: {'f170lp'}
#     opt_elem2: {'g235h'}
#     target: {'1'}
#     program: {'84600'}
#     instrument: {'nirspec'}
#     asn_candidate: {"\\(\\'o041\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o041_t001_nirspec_f170lp-g235h with 2 members
# jw84600-o039_tso3_001_asn with 1 products
# Rule=candidate_Asn_TSO_EXPTYPE
# Constraints:
#     exp_type: {'nrs_brightobj'}
#     no_tso_flag: Is Invalid
#     opt_elem: {'f070lp'}
#     opt_elem2: {'g140h'}
#     target: {'1'}
#     program: {'84600'}
#     instrument: {'nirspec'}
#     asn_candidate: {"\\(\\'o039\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o039_t001_nirspec_f070lp-g140h with 1 members
# jw84600-o042_tso3_001_asn with 1 products
# Rule=candidate_Asn_TSO_EXPTYPE
# Constraints:
#     exp_type: {'nrs_brightobj'}
#     no_tso_flag: Is Invalid
#     opt_elem: {'f170lp'}
#     opt_elem2: {'g235h'}
#     target: {'1'}
#     program: {'84600'}
#     instrument: {'nirspec'}
#     asn_candidate: {"\\(\\'o042\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o042_t001_nirspec_f170lp-g235h with 2 members
# jw84600-o012_spec3_002_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f100lp'}
#     opt_elem2: {'g140h'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o012\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o012_t001_nirspec_f100lp-g140h with 2 members
# jw84600-o012_spec3_003_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f070lp'}
#     opt_elem2: {'g140h'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o012\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o012_t001_nirspec_f070lp-g140h with 2 members
# jw84600-o011_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f170lp'}
#     opt_elem2: {'g235m'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o011\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o011_t001_nirspec_f170lp-g235m with 2 members
# jw84600-o010_spec3_002_asn with 1 products
# Rule=candidate_Asn_NRS_MSA
# Constraints:
#     exp_type: {'nrs_msaspec', 'nrs_autoflat'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     opt_elem: {'f070lp'}
#     opt_elem2: {'g140m'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o010\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o010_t001_nirspec_f070lp-g140m with 4 members
# jw84600-o006_spec3_001_asn with 1 products
# Rule=candidate_Asn_NRS_IFU
# Constraints:
#     exp_type: {'nrs_ifu'}
#     is_not_tso: set()
#     instrument: {'nirspec'}
#     target: {'1'}
#     program: {'84600'}
#     asn_candidate: {"\\(\\'o006\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw84600-o006_t001_nirspec_clear with 2 members
# Association jw84600-o017_image2_298_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2ImageNonScience
#         Program:      84600
#         Target:       1
#         Pool:         jw84600_20171108T041344_fixed_pool
#         Constraints:
#             single_science: {'False'}
#             non_science: {'nrs_focus'}
#             program: {'84600'}
#             target: {'1'}
#             instrument: {'nirspec'}
#             detector: {'nrs2'}
#             opt_elem: {'f140x'}
#             opt_elem2: {'mirror'}
#             subarray: {'full'}
#             channel: set()
#             asn_candidate: {"\\(\\'o017\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw84600017001_02101_00006_nrs2 with 1 members
# 	jw84600036001_02101_00001_nrs1 with 1 members
# 	jw84600035001_02101_00001_nrs2 with 1 members
# 	jw84600018001_02101_00001_nrs2 with 1 members
# 	jw84600016001_02101_00002_nrs1 with 1 members
# 	jw84600016001_02101_00002_nrs2 with 1 members
# 	jw84600017001_02101_00002_nrs1 with 1 members
# 	jw84600017001_02101_00006_nrs1 with 1 members
# 	jw84600017001_02101_00003_nrs1 with 1 members
# 	jw84600017001_02101_00005_nrs2 with 1 members
# 	jw84600010001_02101_00001_nrs2 with 1 members
# 	jw84600017001_02101_00001_nrs2 with 1 members
# 	jw84600018001_02101_00002_nrs1 with 1 members
# 	jw84600016001_02101_00001_nrs2 with 1 members
# 	jw84600017001_02101_00003_nrs2 with 1 members
# 	jw84600010001_02101_00001_nrs1 with 1 members
# 	jw84600017001_02101_00001_nrs1 with 1 members
# 	jw84600010001_02102_00001_nrs2 with 1 members
# 	jw84600010001_02102_00001_nrs1 with 1 members
# 	jw84600018001_02101_00001_nrs1 with 1 members
# 	jw84600016001_02101_00001_nrs1 with 1 members
# 	jw84600017001_02101_00002_nrs2 with 1 members
# 	jw84600017001_02101_00004_nrs1 with 1 members
# 	jw84600035001_02101_00001_nrs1 with 1 members
# 	jw84600017001_02101_00005_nrs1 with 1 members
# 	jw84600018001_02101_00002_nrs2 with 1 members
# 	jw84600017001_02101_00004_nrs2 with 1 members
#
#
# Association jw84600-o007_spec2_299_asn
#     Parameters:
#         Product type: spec2
#         Rule:         candidate_Asn_Lv2Spec
#         Program:      84600
#         Target:       1
#         Pool:         jw84600_20171108T041344_fixed_pool
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrs_ifu'}
#             program: {'84600'}
#             target: {'1'}
#             instrument: {'nirspec'}
#             detector: {'nrs1'}
#             opt_elem: {'f290lp'}
#             opt_elem2: {'g395h'}
#             subarray: {'full'}
#             channel: set()
#             asn_candidate: {"\\(\\'o007\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw84600007001_02101_00001_nrs1 with 1 members
# 	jw84600003001_02104_00001_nrs1 with 1 members
# 	jw84600040001_02101_00001_nrs1 with 1 members
# 	jw84600008001_02101_00002_nrs2 with 1 members
# 	jw84600003001_02103_00001_nrs1 with 1 members
# 	jw84600012001_02101_00001_nrs1 with 1 members
# 	jw84600003001_02101_00001_nrs2 with 1 members
# 	jw84600041001_02101_00001_nrs2 with 1 members
# 	jw84600039001_02101_00001_nrs1 with 1 members
# 	jw84600003001_02104_00001_nrs2 with 1 members
# 	jw84600042001_02101_00001_nrs1 with 1 members
# 	jw84600012001_02102_00001_nrs1 with 1 members
# 	jw84600012001_02103_00001_nrs1 with 1 members
# 	jw84600011001_02101_00001_nrs2 with 1 members
# 	jw84600010001_02101_00002_nrs1 with 1 members
# 	jw84600042001_02101_00001_nrs2 with 1 members
# 	jw84600003001_02102_00001_nrs2 with 1 members
# 	jw84600002001_02101_00001_nrs1 with 1 members
# 	jw84600010001_02102_00002_nrs2 with 1 members
# 	jw84600012001_02103_00001_nrs2 with 1 members
# 	jw84600012001_02101_00001_nrs2 with 1 members
# 	jw84600003001_02101_00001_nrs1 with 1 members
# 	jw84600041001_02101_00001_nrs1 with 1 members
# 	jw84600007001_02101_00001_nrs2 with 1 members
# 	jw84600002001_02101_00001_nrs2 with 1 members
# 	jw84600003001_02103_00001_nrs2 with 1 members
# 	jw84600008001_02101_00002_nrs1 with 1 members
# 	jw84600007001_02102_00001_nrs2 with 1 members
# 	jw84600040001_02101_00001_nrs2 with 1 members
# 	jw84600004001_02101_00001_nrs2 with 1 members
# 	jw84600007001_02102_00001_nrs1 with 1 members
# 	jw84600010001_02101_00002_nrs2 with 1 members
# 	jw84600004001_02102_00001_nrs2 with 1 members
# 	jw84600004001_02101_00001_nrs1 with 1 members
# 	jw84600012001_02102_00001_nrs2 with 1 members
# 	jw84600006001_02101_00001_nrs2 with 1 members
# 	jw84600003001_02102_00001_nrs1 with 1 members
# 	jw84600011001_02101_00001_nrs1 with 1 members
# 	jw84600010001_02102_00002_nrs1 with 1 members
# 	jw84600004001_02102_00001_nrs1 with 1 members
# 	jw84600006001_02101_00001_nrs1 with 1 members
