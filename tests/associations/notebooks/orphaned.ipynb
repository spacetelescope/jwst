# %% [markdown]
# # Abstract

# %% [markdown]
# Experiment/test orphaning

# %%
# Setup debugging log
import logging
logger = logging.getLogger('jwst.associations')
handler = logging.StreamHandler()
logger.addHandler(handler)
handler.setLevel(logging.DEBUG)
logger.setLevel(logging.DEBUG)

# %% [markdown]
# # Environment

# %%
import numpy as np
import pdb

# %%
from jwst.associations import (
    AssociationRegistry,
    generate
)
from jwst.associations.main import Main

# %%
from jwst.associations.tests.helpers import (
    combine_pools,
    registry_level3_only,
    registry_level2_only,
    t_path,
)

# %% [markdown]
# # Library

# %% [markdown]
# # Main

# %% [markdown]
# ## Pool

# %%
pool = combine_pools('../data/pool_001_candidates.csv')

# %% [markdown]
# ## Command line

# %%
def_args = [
    '--dry-run',
    '-D',
]

# %%
results = Main(
    def_args,
    pool=pool
)
# Out:
# Command-line arguments: ['--dry-run', '-D']
# Reading rules.
# Generating associations.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201712211058:DEBUG:jwst.associations.__init__:# asns found before discover filtering=232
# There where 29 associations and 2 orphaned items found.
# Associations found are:
# jw99009-a3001_image3_001_asn with 1 products
# Rule=discover_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
# Products:
# 	jw99009-a3001_t001_nircam_f090w with 56 members
# jw99009-a3001_image3_002_asn with 1 products
# Rule=discover_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
# Products:
# 	jw99009-a3001_t001_nircam_f277w with 14 members
# jw99009-o001_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o001_t001_nircam_f090w with 8 members
# jw99009-o001_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o001_t001_nircam_f277w with 2 members
# jw99009-o002_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o002\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o002_t001_nircam_f090w with 8 members
# jw99009-o002_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o002\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o002_t001_nircam_f277w with 2 members
# jw99009-o003_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o003\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o003_t001_nircam_f090w with 8 members
# jw99009-c1000_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'c1000\\'\\,\\ \\'mosaic\\'\\)"}
# Products:
# 	jw99009-c1000_t001_nircam_f090w with 16 members
# jw99009-c1001_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'c1001\\'\\,\\ \\'mosaic\\'\\)"}
# Products:
# 	jw99009-c1001_t001_nircam_f090w with 24 members
# jw99009-o003_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o003\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o003_t001_nircam_f277w with 2 members
# jw99009-c1000_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'c1000\\'\\,\\ \\'mosaic\\'\\)"}
# Products:
# 	jw99009-c1000_t001_nircam_f277w with 4 members
# jw99009-c1001_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'c1001\\'\\,\\ \\'mosaic\\'\\)"}
# Products:
# 	jw99009-c1001_t001_nircam_f277w with 6 members
# jw99009-o004_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o004\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o004_t001_nircam_f090w with 8 members
# jw99009-o004_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o004\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o004_t001_nircam_f277w with 2 members
# jw99009-o005_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o005\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o005_t001_nircam_f090w with 8 members
# jw99009-o005_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o005\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o005_t001_nircam_f277w with 2 members
# jw99009-o006_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o006\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o006_t001_nircam_f090w with 8 members
# jw99009-c1002_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'c1002\\'\\,\\ \\'mosaic\\'\\)"}
# Products:
# 	jw99009-c1002_t001_nircam_f090w with 16 members
# jw99009-o006_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o006\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o006_t001_nircam_f277w with 2 members
# jw99009-c1002_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'c1002\\'\\,\\ \\'mosaic\\'\\)"}
# Products:
# 	jw99009-c1002_t001_nircam_f277w with 4 members
# jw99009-o007_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f090w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o007\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o007_t001_nircam_f090w with 8 members
# jw99009-o007_image3_002_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: {'prime_targeted_fixed'}
#     exp_type: {'nrc_image'}
#     is_not_tso: set()
#     opt_elem: {'f277w'}
#     opt_elem2: {'clear'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'nircam'}
#     asn_candidate: {"\\(\\'o007\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o007_t001_nircam_f277w with 2 members
# Association jw99009-o001_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00001 with 1 members
# 	jw_00002 with 1 members
# 	jw_00003 with 1 members
# 	jw_00004 with 1 members
# 	jw_00005 with 1 members
# 	jw_00006 with 1 members
# 	jw_00007 with 1 members
# 	jw_00008 with 1 members
# 	jw_00009 with 1 members
# 	jw_00010 with 1 members
#
#
# Association jw99009-o002_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o002\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00011 with 1 members
# 	jw_00012 with 1 members
# 	jw_00013 with 1 members
# 	jw_00014 with 1 members
# 	jw_00015 with 1 members
# 	jw_00016 with 1 members
# 	jw_00017 with 1 members
# 	jw_00018 with 1 members
# 	jw_00019 with 1 members
# 	jw_00020 with 1 members
#
#
# Association jw99009-o003_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o003\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00021 with 1 members
# 	jw_00022 with 1 members
# 	jw_00023 with 1 members
# 	jw_00024 with 1 members
# 	jw_00025 with 1 members
# 	jw_00026 with 1 members
# 	jw_00027 with 1 members
# 	jw_00028 with 1 members
# 	jw_00029 with 1 members
# 	jw_00030 with 1 members
#
#
# Association jw99009-o004_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o004\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00031 with 1 members
# 	jw_00032 with 1 members
# 	jw_00033 with 1 members
# 	jw_00034 with 1 members
# 	jw_00035 with 1 members
# 	jw_00036 with 1 members
# 	jw_00037 with 1 members
# 	jw_00038 with 1 members
# 	jw_00039 with 1 members
# 	jw_00040 with 1 members
#
#
# Association jw99009-o005_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o005\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00041 with 1 members
# 	jw_00042 with 1 members
# 	jw_00043 with 1 members
# 	jw_00044 with 1 members
# 	jw_00045 with 1 members
# 	jw_00046 with 1 members
# 	jw_00047 with 1 members
# 	jw_00048 with 1 members
# 	jw_00049 with 1 members
# 	jw_00050 with 1 members
#
#
# Association jw99009-o006_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o006\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00051 with 1 members
# 	jw_00052 with 1 members
# 	jw_00053 with 1 members
# 	jw_00054 with 1 members
# 	jw_00055 with 1 members
# 	jw_00056 with 1 members
# 	jw_00057 with 1 members
# 	jw_00058 with 1 members
# 	jw_00059 with 1 members
# 	jw_00060 with 1 members
#
#
# Association jw99009-o007_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_001_candidates
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nrc_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'nircam'}
#             detector: {'nrca1'}
#             opt_elem: {'f090w'}
#             opt_elem2: {'clear'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o007\\'\\,\\ \\'observation\\'\\)"}
#             is_tso: set()
# 	jw_00061 with 1 members
# 	jw_00062 with 1 members
# 	jw_00063 with 1 members
# 	jw_00064 with 1 members
# 	jw_00065 with 1 members
# 	jw_00066 with 1 members
# 	jw_00067 with 1 members
# 	jw_00068 with 1 members
# 	jw_00069 with 1 members
# 	jw_00070 with 1 members

# %%
len(results.associations)
# Out:
# 29

# %%
len(results.orphaned)
# Out:
# 2

# %%
len(pool)
# Out:
# 72

# %%
results.orphaned
# Out:
# <AssociationPool length=2>
# filename program obs_num       visitype       ... grating asn_candidate tsovisit
#  str25     str7   str14         str20         ...   str7      str95       str8
# -------- ------- ------- -------------------- ... ------- ------------- --------
# set acid program obs_num             visitype ... grating          1000 tsovisit
# set acid program obs_num prime_targeted_fixed ... grating          1002 tsovisit
