# %% [markdown]
# # Abstract

# %% [markdown]
# Reduce the size of the dataset

# %% [markdown]
# # Environment

# %%
import numpy as np

# %%
from jwst.datamodels import open as dm_open
from jwst.datamodels import (ImageModel, MultiSlitModel)
from jwst.exp_to_source import exp_to_source

# %% [markdown]
# # Library

# %% [markdown]
# # Main

# %% [markdown]
# Create the small data

# %%
data = np.ones((10, 10))

# %%
new_ms = MultiSlitModel()

# %%
ori_ms = dm_open('ori_jwst_nod1_cal.fits')

# %%
for idx, name in enumerate(['S200A1', 'S200A2', 'S1600A1', 'S400A1', 'S200B1']):
    new_ms.slits.append(ImageModel(data=data))
    new_ms.slits[idx].name = name
    new_ms.slits[idx].source_id = idx + 1
    new_ms.slits[idx].meta.wcs = ori_ms.slits[idx].meta.wcs

# %%
new_ms.update(ori_ms)

# %%
for slit in new_ms.slits:
    print(slit.name)
    print(slit.meta.wcs.available_frames)
# Out:
# S200A1
# ['detector', 'sca', 'gwa', 'slit_frame', 'msa_frame', 'oteip', 'v2v3', 'world']
# S200A2
# ['detector', 'sca', 'gwa', 'slit_frame', 'msa_frame', 'oteip', 'v2v3', 'world']
# S1600A1
# ['detector', 'sca', 'gwa', 'slit_frame', 'msa_frame', 'oteip', 'v2v3', 'world']
# S400A1
# ['detector', 'sca', 'gwa', 'slit_frame', 'msa_frame', 'oteip', 'v2v3', 'world']
# S200B1
# ['detector', 'sca', 'gwa', 'slit_frame', 'msa_frame', 'oteip', 'v2v3', 'world']

# %% [markdown]
# Save out the new dataset

# %%
new_ms.save('../jwst_nod1_cal.fits')
new_ms.save('../jwst_nod2_cal.fits')
new_ms.save('../jwst_nod3_cal.fits')
# Out:
# '../jwst_nod3_cal.fits'

# %% [markdown]
# Attempt the test

# %%
# %%bash
# pytest ../../test_exp_to_source.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.7, pytest-3.9.1, py-1.7.0, pluggy-0.8.0
# rootdir: /internal/1/astropy/jwst, inifile: setup.cfg
# plugins: requests-mock-1.5.2, remotedata-0.3.0, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2, ci-watson-0.3
#
# ========================= no tests ran in 0.00 seconds =========================
# ERROR: file not found: ../../test_exp_to_source.py
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-10-c167fe9685e1> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'pytest ../../test_exp_to_source.py\n')
#
# /user/dencheva/anaconda3/envs/jwstdev/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2319             magic_arg_s = self.var_expand(line, stack_depth)
#    2320             with self.builtin_trap:
# -> 2321                 result = fn(magic_arg_s, cell)
#    2322             return result
#    2323
#
# /user/dencheva/anaconda3/envs/jwstdev/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-109> in shebang(self, line, cell)
#
# /user/dencheva/anaconda3/envs/jwstdev/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /user/dencheva/anaconda3/envs/jwstdev/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'pytest ../../test_exp_to_source.py\n'' returned non-zero exit status 4.
