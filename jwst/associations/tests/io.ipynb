# %% [markdown]
# # Abstract

# %% [markdown]
# Test issues from test_io

# %% [markdown]
# # Environment

# %%
from jwst.associations.tests.helpers import (
    combine_pools,
    full_pool_rules,
)

# %%
from jwst.associations import (
    AssociationPool,
    AssociationRegistry,
    generate
)
from jwst.associations.main import Main

# %% [markdown]
# # Library

# %% [markdown]
# # Main

# %% [markdown]
# ## Using Main

# %%
generated = Main([
    'data/mega_pool.csv',
    '-p', '/tmp',
    '--save-orphans',
    '--format', 'yaml'
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a2448908d664> in <module>()
#       3     '-p', '/tmp',
#       4     '--save-orphans',
# ----> 5     '--format', 'yaml'
#       6 ])
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/main.py in __init__(self, args, pool)
#     238         logger.info('Generating associations.')
#     239         self.associations, self.orphaned = generate(
# --> 240             self.pool, self.rules, version_id=parsed.version_id
#     241         )
#     242
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/generate.py in generate(pool, rules, version_id)
#      65                 associations,
#      66                 rules,
# ---> 67                 process_item.rules
#      68             )
#      69             associations.extend(new_asns)
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/generate.py in generate_from_member(member, version_id, associations, rules, allowed_rules)
#     140         version_id=version_id,
#     141         allow=allowed_rules,
# --> 142         ignore=ignore_asns,
#     143     )
#     144     logger.debug(
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/registry.py in match(self, member, version_id, allow, ignore)
#     157             if rule not in ignore and rule in allow:
#     158                 logger.debug('Checking membership for rule "{}"'.format(rule))
# --> 159                 asn, reprocess = rule.create(member, version_id)
#     160                 process_list.extend(reprocess)
#     161                 if asn is None:
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/association.py in create(cls, member, version_id)
#     138         """
#     139         asn = cls(version_id=version_id)
# --> 140         matches, reprocess = asn.add(member)
#     141         if not matches:
#     142             return None, reprocess
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/association.py in add(self, member, check_constraints)
#     336         if matches:
#     337             if self.run_init_hook:
# --> 338                 self._init_hook(member)
#     339             self._add(member)
#     340             self.run_init_hook = False
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/rules_level2_base.py in _init_hook(self, member)
#     451         """Post-check and pre-add initialization"""
#     452
# --> 453         super(AsnMixin_Lv2Image, self)._init_hook(member)
#     454         self.data['asn_type'] = 'image2'
#     455
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/rules_level2_base.py in _init_hook(self, member)
#     189             [cc for cc in self.constraints_to_text()]
#     190         )
# --> 191         self.data['asn_id'] = self.acid.id
#     192         self.new_product(self.dms_product_name())
#     193
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/dms_base.py in acid(self)
#      22     def acid(self):
#      23         """Association ID"""
# ---> 24         return self.acid_from_constraints()
#      25
#      26     @property
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/acid.py in acid_from_constraints(self)
#      65         for _, constraint in self.constraints.items():
#      66             if constraint.get('is_acid', False):
# ---> 67                 value = re.sub('\\\\', '', constraint['value'])
#      68                 try:
#      69                     acid = ACID(value)
#
# /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/re.py in sub(pattern, repl, string, count, flags)
#     180     a callable, it's passed the match object and must return
#     181     a replacement string to be used."""
# --> 182     return _compile(pattern, flags).sub(repl, string, count)
#     183
#     184 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# %debug
# Out:
# > /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/re.py(182)sub()
#     180     a callable, it's passed the match object and must return
#     181     a replacement string to be used."""
# --> 182     return _compile(pattern, flags).sub(repl, string, count)
#     183
#     184 def subn(pattern, repl, string, count=0, flags=0):
#
# ipdb> pattern
# '\\\\'
# ipdb> u
# > /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/acid.py(67)acid_from_constraints()
#      65         for _, constraint in self.constraints.items():
#      66             if constraint.get('is_acid', False):
# ---> 67                 value = re.sub('\\\\', '', constraint['value'])
#      68                 try:
#      69                     acid = ACID(value)
#
# ipdb> constraint
# {'force_unique': True, 'value': None, 'is_acid': True, 'inputs': ['ASN_CANDIDATE']}
# ipdb> u
# > /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/dms_base.py(24)acid()
#      22     def acid(self):
#      23         """Association ID"""
# ---> 24         return self.acid_from_constraints()
#      25
#      26     @property
#
# ipdb> u
# > /Users/eisenham/anaconda3/envs/asnopt_py3/lib/python3.5/site-packages/jwst-0.7.7.dev491-py3.5-macosx-10.7-x86_64.egg/jwst/associations/lib/rules_level2_base.py(191)_init_hook()
#     189             [cc for cc in self.constraints_to_text()]
#     190         )
# --> 191         self.data['asn_id'] = self.acid.id
#     192         self.new_product(self.dms_product_name())
#     193
#
# ipdb> l
#     186             member.meta['pool_file']
#     187         ).split('.')[0]
#     188         self.data['constraints'] = '\n'.join(
#     189             [cc for cc in self.constraints_to_text()]
#     190         )
# --> 191         self.data['asn_id'] = self.acid.id
#     192         self.new_product(self.dms_product_name())
#     193
#     194     def _add(self, member, check_flags=None):
#     195         """Add member to this association.
#     196
#
# ipdb> self.constraints
# {'program': {'force_unique': False, 'value': '99009', 'inputs': ['PROGRAM']}, 'exp_type': {'force_unique': False, 'value': 'NRC_IMAGE', 'inputs': ['EXP_TYPE']}, 'single_science': {'test': <bound method Association.match_constraint of <class 'abc.candidate_Asn_Lv2Image'>>, 'value': 'False', 'inputs': <function AsnMixin_Lv2Singleton.__init__.<locals>.<lambda> at 0x10b481c80>}, 'detector': {'force_unique': False, 'value': 'NRCA1', 'inputs': ['DETECTOR']}, 'asn_candidate': {'force_unique': True, 'value': None, 'is_acid': True, 'inputs': ['ASN_CANDIDATE']}, 'opt_elem2': {'force_unique': False, 'value': 'CLEAR', 'inputs': ['PUPIL'], 'required': False}, 'opt_elem': {'force_unique': False, 'value': 'F090W', 'inputs': ['FILTER']}, 'channel': {'value': None, 'inputs': ['CHANNEL'], 'required': False}, 'instrument': {'force_unique': False, 'value': 'NIRCAM', 'inputs': ['INSTRUME']}, 'subarray': {'value': None, 'inputs': ['SUBARRAY'], 'required': False}}
# ipdb> q

# %% [markdown]
# ## Totally by code

# %%
rules = AssociationRegistry()

# %%
pool = AssociationPool.read('data/mega_pool.csv')

# %%
asns, orphaned = generate(pool, rules)
