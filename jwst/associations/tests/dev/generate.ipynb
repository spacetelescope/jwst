# %% [markdown]
# # Association Generator: GenerateScript

# %% [markdown]
# ## Environment Setup

# %%
# %autoreload 2

import sys
import warnings
    
sys.path.insert(1, '../../jwst_tools/associations/')

# %%
from generate import GenerateScript

# %% [markdown]
# ### Check basic usage

# %%
#GenerateScript('--help')

# %% [markdown]
# ## Examples

# %% [markdown]
# ### MIRI Example

# %%
argv = '../data/jw93060_001_01_pool.csv ../data/association_definitions.py'
miri = GenerateScript(argv)
# Out:
# There where 6 associations found.
# Association jw93060_01-001_dither_20140724T012846_asn
#     Parameters:
#         Product type: dither
#         Rule:         Asn_MIRI_Dither
#         Program:      93060
#         Target:       NGC-3603
#         Pool:         jw93060_001_01_pool
#         Constraints:
#             pointing_type: SCIENCE
#             instrument: MIRI
#             opt_elem: F560W
#
#     Products:
#         Product jw93060_NGC-3603_MIRI_F560W_dither.fits:
#             jw93060001001_01101_00001_MIRIM_image: SCIENCE
#             jw93060001001_01101_00002_MIRIM_image: SCIENCE
#             jw93060001001_01101_00003_MIRIM_image: SCIENCE
#             jw93060001001_01101_00004_MIRIM_image: SCIENCE
#             jw93060001001_01101_00005_MIRIM_image: SCIENCE
#             jw93060001002_01101_00001_MIRIM_image: SCIENCE
#             jw93060001002_01101_00002_MIRIM_image: SCIENCE
#             jw93060001002_01101_00003_MIRIM_image: SCIENCE
# ...

# %%
argv = '../data/jw93060_001_01_pool.csv ../data/association_definitions.py -s -p /tmp/'
miri = GenerateScript(argv)

# %%
argv = '../data/jw93060_001_01_pool.csv ../data/association_definitions.py -s -p /tmp/ -f fits'
miri = GenerateScript(argv)

# %% [markdown]
# ### NIRCam Example

# %%
argv = '../data/jw93060_002_01_pool.csv ../data/association_definitions.py'
nircam = GenerateScript(argv)
# Out:
# There where 8 associations found.
# Association jw93060_01-001_dither_20140724T012916_asn
#     Parameters:
#         Product type: dither
#         Rule:         Asn_NIRCam_Dither
#         Program:      93060
#         Target:       NGC-3603
#         Pool:         jw93060_002_01_pool
#         Constraints:
#             pointing_type: SCIENCE
#             instrument: NIRCAM
#             opt_elem: F090W
#
#     Products:
#         Product jw93060_NGC-3603_NIRCAM_F090W_dither.fits:
#             jw93060002001_01101_00001_NRCA1_image: SCIENCE
#             jw93060002001_01101_00001_NRCA2_image: SCIENCE
#             jw93060002001_01101_00001_NRCA3_image: SCIENCE
#             jw93060002001_01101_00001_NRCA4_image: SCIENCE
#             jw93060002001_01101_00001_NRCB1_image: SCIENCE
#             jw93060002001_01101_00001_NRCB2_image: SCIENCE
#             jw93060002001_01101_00001_NRCB3_image: SCIENCE
#             jw93060002001_01101_00001_NRCB4_image: SCIENCE
# ...

# %%
argv = '../data/jw93060_002_01_pool.csv ../data/association_definitions.py -s -p /tmp/'
nircam = GenerateScript(argv)

# %%
argv = '../data/jw93060_002_01_pool.csv ../data/association_definitions.py -s -p /tmp/ -f fits'
nircam = GenerateScript(argv)
