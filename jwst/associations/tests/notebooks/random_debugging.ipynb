# %% [markdown]
# # Abstract

# %%
# Setup debugging log
import logging
logger = logging.getLogger('jwst.associations')
handler = logging.StreamHandler()
logger.addHandler(handler)
handler.setLevel(logging.DEBUG)
logger.setLevel(logging.DEBUG)

# %% [markdown]
# # Environment

# %%
import numpy as np
import pdb

# %%
from jwst.associations import (
    AssociationPool,
    AssociationRegistry,
    generate
)
from jwst.associations.main import Main

# %%
from jwst.associations.tests.helpers import (
    combine_pools,
    registry_level3_only,
    registry_level2_only,
    t_path,
)

# %% [markdown]
# # Library

# %% [markdown]
# # Main

# %% [markdown]
# ## Level2 and NRS_LAMP

# %%
jw96215 = AssociationPool.read('../data/sdp/pools/jw96215_20180602T170215_pool.csv')

# %%
jw96215['targetid']
# Out:
# <Column name='targetid' dtype='str4' length=12>
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null
# null

# %%
reg_lv2 = registry_level2_only()

# %%
Lv2NRSLAMP = reg_lv2['Asn_Lv2NRSLAMP']

# %%
create = Lv2NRSLAMP.create(jw96215[0])
# Out:
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint SimpleConstraint({'name': 'single_science', 'value': False})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Constraint ConstraintTrue({'name': None, 'value': None})
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201933:DEBUG:jwst.associations.lib.constraint.all:Reprocess []

# %%
create
# Out:
# ({
#      "asn_type": "spec2-nrslamp",
#      "asn_rule": "Asn_Lv2NRSLAMP",
#      "version_id": null,
#      "code_version": "0.9.19",
#      "degraded_status": "No known degraded exposures in association.",
#      "program": "96215",
#      "target": "null",
#      "asn_pool": "jw96215_20180602T170215_pool",
#      "constraints": "DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})\nDMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})\nDMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})\nDMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})\nDMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})\nDMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})\nDMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})\nDMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})\nSimpleConstraint({'name': 'single_science', 'value': False})",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw96215001001_02107_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02107_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          }
#      ]
#  }, [])

# %%
asn = create[0]

# %%
asn
# Out:
# {
#     "asn_type": "spec2-nrslamp",
#     "asn_rule": "Asn_Lv2NRSLAMP",
#     "version_id": null,
#     "code_version": "0.9.19",
#     "degraded_status": "No known degraded exposures in association.",
#     "program": "96215",
#     "target": "null",
#     "asn_pool": "jw96215_20180602T170215_pool",
#     "constraints": "DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})\nDMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})\nDMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})\nDMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})\nDMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})\nDMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})\nDMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})\nDMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})\nSimpleConstraint({'name': 'single_science', 'value': False})",
#     "asn_id": "a3001",
#     "products": [
#         {
#             "name": "jw96215001001_02107_00001_nrs1",
#             "members": [
#                 {
#                     "expname": "jw96215001001_02107_00001_nrs1_rate.fits",
#                     "exptype": "science",
#                     "exposerr": "null"
#                 }
#             ]
#         }
#     ]
# }

# %%
asn.validity.keys()
# Out:
# dict_keys(['has_science', 'allowed_candidates'])

# %%
asn.validity['has_science']
# Out:
# {'validated': True,
#  'check': <function jwst.associations.lib.rules_level2_base.DMSLevel2bBase.__init__.<locals>.<lambda>(member)>}

# %%
asn.validity['allowed_candidates']
# Out:
# {'validated': False,
#  'check': <bound method DMSLevel2bBase.validate_candidates of {
#      "asn_type": "spec2-nrslamp",
#      "asn_rule": "Asn_Lv2NRSLAMP",
#      "version_id": null,
#      "code_version": "0.9.19",
#      "degraded_status": "No known degraded exposures in association.",
#      "program": "96215",
#      "target": "null",
#      "asn_pool": "jw96215_20180602T170215_pool",
#      "constraints": "DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})\nDMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})\nDMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})\nDMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})\nDMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})\nDMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})\nDMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})\nDMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})\nSimpleConstraint({'name': 'single_science', 'value': False})",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw96215001001_02107_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02107_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          }
#      ]
#  }>}

# %%
asn.acid.type
# Out:
# 'DISCOVERED'

# %%
reg_nrslamp = registry_level2_only()

# %%
for rule_id in list(reg_nrslamp):
    if rule_id != 'Asn_Lv2NRSLAMP':
        del reg_nrslamp[rule_id]

# %%
reg_nrslamp
# Out:
# {'Asn_Lv2NRSLAMP': abc.Asn_Lv2NRSLAMP}

# %%
jw96215_0 = AssociationPool(jw96215[0])

# %%
jw96215_asns = generate(jw96215_0, reg_nrslamp)
# Out:
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint SimpleConstraint({'name': 'single_science', 'value': False})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Constraint ConstraintTrue({'name': None, 'value': None})
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806201931:DEBUG:jwst.associations.lib.constraint.all:Reprocess []

# %%
jw96215_asns
# Out:
# []

# %%
reg_lv2

# %%
jw96215[0]

# %%
pdb.runcall(Lv2NRSLAMP.create, jw96215[0])

# %%
jw96215_generated = Main(
    ['--dry-run', '-D', '--all-candidates'],
    pool= jw96215
)
# Out:
# Command-line arguments: ['--dry-run', '-D', '--all-candidates']
# Reading rules.
# Generating associations.
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'fgs_image|fgs_focus'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'fgs_image|fgs_focus'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'fgs_image|fgs_focus'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint Constraint_Image_Science({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'mir_image|mir_lyot|mir_4qpm|nis_ami|nis_image|nrc_image|nrc_coron|nrc_tsimage'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# Constraint_Image_Science({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'mir_image|mir_lyot|mir_4qpm|nis_ami|nis_image|nrc_image|nrc_coron|nrc_tsimage'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# Constraint_Image_Science({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'mir_image|mir_lyot|mir_4qpm|nis_ami|nis_image|nrc_image|nrc_coron|nrc_tsimage'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'non_science', 'sources': ['exp_type'], 'value': 'mir_coroncal|mir_tacq|nis_focus|nis_tacq|nis_taconfirm|nrc_tacq|nrc_taconfirm|nrc_focus|nrs_bota|nrs_confirm|nrs_focus|nrs_image|nrs_mimf|nrs_taslit|nrs_tacq|nrs_taconfirm'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'non_science', 'sources': ['exp_type'], 'value': 'mir_coroncal|mir_tacq|nis_focus|nis_tacq|nis_taconfirm|nrc_tacq|nrc_taconfirm|nrc_focus|nrs_bota|nrs_confirm|nrs_focus|nrs_image|nrs_mimf|nrs_taslit|nrs_tacq|nrs_taconfirm'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'non_science', 'sources': ['exp_type'], 'value': 'mir_coroncal|mir_tacq|nis_focus|nis_tacq|nis_taconfirm|nrc_tacq|nrc_taconfirm|nrc_focus|nrs_bota|nrs_confirm|nrs_focus|nrs_image|nrs_mimf|nrs_taslit|nrs_tacq|nrs_taconfirm'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint Constraint_Image_Science({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'mir_image|mir_lyot|mir_4qpm|nis_ami|nis_image|nrc_image|nrc_coron|nrc_tsimage'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# Constraint_Image_Science({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'mir_image|mir_lyot|mir_4qpm|nis_ami|nis_image|nrc_image|nrc_coron|nrc_tsimage'})
# Constraint_Special({'name': 'is_special', 'sources': ['bkgdtarg', 'is_psf'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# Constraint_Image_Science({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'mir_image|mir_lyot|mir_4qpm|nis_ami|nis_image|nrc_image|nrc_coron|nrc_tsimage'})
# Constraint_Special({'name': 'is_special', 'sources': ['bkgdtarg', 'is_psf'], 'value': None})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'asn_candidate', 'sources': ['asn_candidate'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess [<jwst.associations.lib.process_list.ProcessList object at 0x813337cc0>]
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrc_grism|nrc_tsgrism|nrc_wfss|mir_lrs-fixedslit|mir_lrs-slitless|mir_mrs|nrs_fixedslit|nrs_ifu|nrs_brightobj|nis_soss|nis_wfss'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrc_grism|nrc_tsgrism|nrc_wfss|mir_lrs-fixedslit|mir_lrs-slitless|mir_mrs|nrs_fixedslit|nrs_ifu|nrs_brightobj|nis_soss|nis_wfss'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrc_grism|nrc_tsgrism|nrc_wfss|mir_lrs-fixedslit|mir_lrs-slitless|mir_mrs|nrs_fixedslit|nrs_ifu|nrs_brightobj|nis_soss|nis_wfss'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrc_grism|nrc_tsgrism|nrc_wfss|mir_lrs-fixedslit|mir_lrs-slitless|mir_mrs|nrs_fixedslit|nrs_ifu|nrs_brightobj|nis_soss|nis_wfss'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrc_grism|nrc_tsgrism|nrc_wfss|mir_lrs-fixedslit|mir_lrs-slitless|mir_mrs|nrs_fixedslit|nrs_ifu|nrs_brightobj|nis_soss|nis_wfss'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# Constraint_Special({'name': 'is_special', 'sources': ['bkgdtarg', 'is_psf'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrc_grism|nrc_tsgrism|nrc_wfss|mir_lrs-fixedslit|mir_lrs-slitless|mir_mrs|nrs_fixedslit|nrs_ifu|nrs_brightobj|nis_soss|nis_wfss'})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_msaspec'})
# Constraint_Special({'name': 'is_special', 'sources': ['bkgdtarg', 'is_psf'], 'value': None})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nis_wfss'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# ...
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs2'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs2'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs2'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs2'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs2'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs2'})
# DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# DMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})
# SimpleConstraint({'name': 'single_science', 'value': False})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? False
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# DMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Reprocess []
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Constraint DMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})
# 201806202056:DEBUG:jwst.associations.lib.constraint.all:Matched? True

# %%
jw96215_generated.associations
# Out:
# [{
#      "asn_type": "spec2-nrslamp",
#      "asn_rule": "candidate_Asn_Lv2NRSLAMP",
#      "version_id": null,
#      "code_version": "0.9.19",
#      "degraded_status": "No known degraded exposures in association.",
#      "program": "96215",
#      "target": "null",
#      "asn_pool": "jw96215_20180602T170215_pool",
#      "constraints": "DMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'is_tso', 'sources': ['tsovisit'], 'value': None})\nDMSAttrConstraint({'name': 'program', 'sources': ['program'], 'value': '96215'})\nDMSAttrConstraint({'name': 'instrument', 'sources': ['instrume'], 'value': 'nirspec'})\nDMSAttrConstraint({'name': 'detector', 'sources': ['detector'], 'value': 'nrs1'})\nDMSAttrConstraint({'name': 'opt_elem', 'sources': ['filter'], 'value': 'opaque'})\nDMSAttrConstraint({'name': 'opt_elem2', 'sources': ['grating'], 'value': 'g395m'})\nDMSAttrConstraint({'name': 'subarray', 'sources': ['subarray'], 'value': 'full'})\nDMSAttrConstraint({'name': 'channel', 'sources': ['channel'], 'value': None})\nDMSAttrConstraint({'name': 'exp_type', 'sources': ['exp_type'], 'value': 'nrs_lamp'})\nSimpleConstraint({'name': 'single_science', 'value': False})\nDMSAttrConstraint({'name': 'asn_candidate', 'sources': ['asn_candidate'], 'value': \"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"})",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw96215001001_02107_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02107_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02105_00001_nrs2",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02105_00001_nrs2_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02105_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02105_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02104_00001_nrs2",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02104_00001_nrs2_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02104_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02104_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02106_00001_nrs2",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02106_00001_nrs2_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02102_00001_nrs2",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02102_00001_nrs2_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02103_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02103_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02106_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02106_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02107_00001_nrs2",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02107_00001_nrs2_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02103_00001_nrs2",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02103_00001_nrs2_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          },
#          {
#              "name": "jw96215001001_02102_00001_nrs1",
#              "members": [
#                  {
#                      "expname": "jw96215001001_02102_00001_nrs1_rate.fits",
#                      "exptype": "science",
#                      "exposerr": "null"
#                  }
#              ]
#          }
#      ]
#  }]

# %% [markdown]
# ## MIR_FLATMRS in a Level3 for no reason

# %%
jw80600 = AssociationPool.read('../data/sdp/pools/jw80600_20171108T041522_pool.csv')

# %%
jw80600[jw80600['exp_type'] == 'mir_flatmrs']['filename', 'obs_num', 'exp_type', 'asn_candidate', 'filter']

# %%
jw80600_generated_all = Main(
    ['--dry-run', '-v', '--all-candidates'],
    pool=jw80600
)

# %%
mir_flatmr_obs = set(jw80600[jw80600['exp_type'] == 'mir_flatmrs']['obs_num'])

# %%
mir_flatmr_obs

# %%
mir_flatmr_obs_generated = Main(
    ['--dry-run', '-v', '-i', 'o016', '-i', 'o018', '-i', 'o020', '-i', 'o021', '-i', 'o050', '-i', 'o051'],
    pool=jw80600
)

# %%
jw93135 = AssociationPool.read('../data/sdp/pools/jw93135_20171108T041617_fixed_pool.csv')

# %%
mir_flatmr_obs_jw93135 = set(jw93135[jw93135['exp_type'] == 'mir_flatmrs']['obs_num'])

# %%
mir_flatmr_obs_jw93135

# %%
mir_flat_obs_args_jw93135 = [
    '--dry-run',
    '-v'
]

# %%
for obsnum in mir_flatmr_obs_jw93135:
    mir_flat_obs_args_jw93135.append('-i')
    mir_flat_obs_args_jw93135.append('o{:0>3s}'.format(obsnum))

# %%
mir_flat_obs_args_jw93135

# %%
mir_flatmr_obs_generated_jw93135 = Main(
    mir_flat_obs_args_jw93135,
    pool=jw93135
)

# %%
mir_flatmr_obs_generated_jw93135.associations[0]

# %%
jw93135[jw93135['obs_num'] == '327']['filename', 'exp_type']

# %%
mir_flatmr_obs_generated_jw93135.associations[1]

# %%
jw93135_exptypes = set(jw93135['exp_type'])

# %%
jw93135_exptypes

# %%
len(jw93135[jw93135['exp_type'] == 'mir_flatmrs'])

# %% [markdown]
# ## Level2 NRS_IMAGE

# %%
jw84600 = AssociationPool.read('../data/sdp/pools/jw84600_20171108T041344_fixed_pool.csv')

# %%
jw84600[jw84600['exp_type'] == 'nrs_image']['filename', 'obs_num', 'exp_type', 'asn_candidate', 'filter']

# %%
jw84600_generated_o033 = Main(
    ['--dry-run', '-v', '-i', 'o033'],
    pool=jw84600
)

# %%
jw84600_generated_o033.associations

# %%
jw84600_generated_all = Main(
    ['--dry-run', '-v'],
    pool=jw84600
)

# %%
for asn in jw84600_generated_all.associations:
    for product in asn['products']:
        for member in product['members']:
            if member['expname'] == 'jw84600033001_02101_00001_nrs1_rate.fits':
                print('Found it in asn_type {} product name {}'.format(asn['asn_type'], product['name']))
