# %% [markdown]
# # Abstract

# %% [markdown]
# Check the interaction with discover and all candidates and level2. It is non-deterministic for some reason. After the list refactoring.

# %% [markdown]
# # Environment

# %%
# Setup debugging log
import logging
logger = logging.getLogger('jwst.associations')
handler = logging.StreamHandler()
logger.addHandler(handler)
handler.setLevel(logging.INFO)
logger.setLevel(logging.INFO)

# %%
import pdb

# %%
from jwst.associations.tests.helpers import (
    combine_pools,
    registry_level2_only,
    registry_level3_only,
)

# %%
from jwst.associations import (
    AssociationRegistry,
    generate
)

# %%
from jwst.associations.main import (
    Main,
    constrain_on_candidates
)

# %% [markdown]
# # Library

# %% [markdown]
# # Main

# %%
pool = combine_pools('../data/pool_001_candidates.csv')

# %%
all_candidates = {
    'asn_candidate': constrain_on_candidates(None)
}

# %% [markdown]
# ## Grouping

# %%
asns_discovered, orphaned = generate(pool, registry_level2_only())
# Out:
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201904101154:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-78bda314671f> in <module>
# ----> 1 asns_discovered, orphaned = generate(pool, registry_level2_only())
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
asns_discovered
# Out:
# [{
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00001",
#              "members": [
#                  {
#                      "expname": "jw_00001_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00002",
#              "members": [
#                  {
#                      "expname": "jw_00002_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00003",
#              "members": [
#                  {
#                      "expname": "jw_00003_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00004",
#              "members": [
#                  {
#                      "expname": "jw_00004_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00005",
#              "members": [
#                  {
#                      "expname": "jw_00005_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00006",
#              "members": [
#                  {
#                      "expname": "jw_00006_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00007",
#              "members": [
#                  {
#                      "expname": "jw_00007_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00008",
#              "members": [
#                  {
#                      "expname": "jw_00008_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00009",
#              "members": [
#                  {
#                      "expname": "jw_00009_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00010",
#              "members": [
#                  {
#                      "expname": "jw_00010_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00011",
#              "members": [
#                  {
#                      "expname": "jw_00011_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00012",
#              "members": [
#                  {
#                      "expname": "jw_00012_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00013",
#              "members": [
#                  {
#                      "expname": "jw_00013_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00014",
#              "members": [
#                  {
#                      "expname": "jw_00014_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00015",
#              "members": [
#                  {
#                      "expname": "jw_00015_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00016",
#              "members": [
#                  {
#                      "expname": "jw_00016_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00017",
#              "members": [
#                  {
#                      "expname": "jw_00017_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00018",
#              "members": [
#                  {
#                      "expname": "jw_00018_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00019",
#              "members": [
#                  {
#                      "expname": "jw_00019_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00020",
#              "members": [
#                  {
#                      "expname": "jw_00020_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00021",
#              "members": [
#                  {
#                      "expname": "jw_00021_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00022",
#              "members": [
#                  {
#                      "expname": "jw_00022_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00023",
#              "members": [
#                  {
#                      "expname": "jw_00023_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00024",
#              "members": [
#                  {
#                      "expname": "jw_00024_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00025",
#              "members": [
#                  {
#                      "expname": "jw_00025_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00026",
#              "members": [
#                  {
#                      "expname": "jw_00026_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00027",
#              "members": [
#                  {
#                      "expname": "jw_00027_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00028",
#              "members": [
#                  {
#                      "expname": "jw_00028_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00029",
#              "members": [
#                  {
#                      "expname": "jw_00029_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00030",
#              "members": [
#                  {
#                      "expname": "jw_00030_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00031",
#              "members": [
#                  {
#                      "expname": "jw_00031_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00032",
#              "members": [
#                  {
#                      "expname": "jw_00032_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00033",
#              "members": [
#                  {
#                      "expname": "jw_00033_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00034",
#              "members": [
#                  {
#                      "expname": "jw_00034_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00035",
#              "members": [
#                  {
#                      "expname": "jw_00035_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00036",
#              "members": [
#                  {
#                      "expname": "jw_00036_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00037",
#              "members": [
#                  {
#                      "expname": "jw_00037_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00038",
#              "members": [
#                  {
#                      "expname": "jw_00038_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00039",
#              "members": [
#                  {
#                      "expname": "jw_00039_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00040",
#              "members": [
#                  {
#                      "expname": "jw_00040_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00041",
#              "members": [
#                  {
#                      "expname": "jw_00041_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00042",
#              "members": [
#                  {
#                      "expname": "jw_00042_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00043",
#              "members": [
#                  {
#                      "expname": "jw_00043_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00044",
#              "members": [
#                  {
#                      "expname": "jw_00044_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00045",
#              "members": [
#                  {
#                      "expname": "jw_00045_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00046",
#              "members": [
#                  {
#                      "expname": "jw_00046_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00047",
#              "members": [
#                  {
#                      "expname": "jw_00047_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00048",
#              "members": [
#                  {
#                      "expname": "jw_00048_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00049",
#              "members": [
#                  {
#                      "expname": "jw_00049_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00050",
#              "members": [
#                  {
#                      "expname": "jw_00050_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00051",
#              "members": [
#                  {
#                      "expname": "jw_00051_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00052",
#              "members": [
#                  {
#                      "expname": "jw_00052_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00053",
#              "members": [
#                  {
#                      "expname": "jw_00053_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00054",
#              "members": [
#                  {
#                      "expname": "jw_00054_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00055",
#              "members": [
#                  {
#                      "expname": "jw_00055_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00056",
#              "members": [
#                  {
#                      "expname": "jw_00056_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00057",
#              "members": [
#                  {
#                      "expname": "jw_00057_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00058",
#              "members": [
#                  {
#                      "expname": "jw_00058_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00059",
#              "members": [
#                  {
#                      "expname": "jw_00059_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00060",
#              "members": [
#                  {
#                      "expname": "jw_00060_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00061",
#              "members": [
#                  {
#                      "expname": "jw_00061_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00062",
#              "members": [
#                  {
#                      "expname": "jw_00062_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00063",
#              "members": [
#                  {
#                      "expname": "jw_00063_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00064",
#              "members": [
#                  {
#                      "expname": "jw_00064_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00065",
#              "members": [
#                  {
#                      "expname": "jw_00065_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00066",
#              "members": [
#                  {
#                      "expname": "jw_00066_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00067",
#              "members": [
#                  {
#                      "expname": "jw_00067_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00068",
#              "members": [
#                  {
#                      "expname": "jw_00068_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00069",
#              "members": [
#                  {
#                      "expname": "jw_00069_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    is_tso: set()",
#      "asn_id": "a3001",
#      "products": [
#          {
#              "name": "jw_00070",
#              "members": [
#                  {
#                      "expname": "jw_00070_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }]

# %%
for asn in asns_discovered:
    print('name {} asn_id {}'.format(asn['products'][0]['name'], asn['asn_id']))
# Out:
# name jw_00001 asn_id a3001
# name jw_00002 asn_id a3001
# name jw_00003 asn_id a3001
# name jw_00004 asn_id a3001
# name jw_00005 asn_id a3001
# name jw_00006 asn_id a3001
# name jw_00007 asn_id a3001
# name jw_00008 asn_id a3001
# name jw_00009 asn_id a3001
# name jw_00010 asn_id a3001
# name jw_00011 asn_id a3001
# name jw_00012 asn_id a3001
# name jw_00013 asn_id a3001
# name jw_00014 asn_id a3001
# name jw_00015 asn_id a3001
# name jw_00016 asn_id a3001
# name jw_00017 asn_id a3001
# name jw_00018 asn_id a3001
# name jw_00019 asn_id a3001
# name jw_00020 asn_id a3001
# name jw_00021 asn_id a3001
# name jw_00022 asn_id a3001
# name jw_00023 asn_id a3001
# name jw_00024 asn_id a3001
# name jw_00025 asn_id a3001
# name jw_00026 asn_id a3001
# name jw_00027 asn_id a3001
# name jw_00028 asn_id a3001
# name jw_00029 asn_id a3001
# name jw_00030 asn_id a3001
# name jw_00031 asn_id a3001
# name jw_00032 asn_id a3001
# name jw_00033 asn_id a3001
# name jw_00034 asn_id a3001
# name jw_00035 asn_id a3001
# name jw_00036 asn_id a3001
# name jw_00037 asn_id a3001
# name jw_00038 asn_id a3001
# name jw_00039 asn_id a3001
# name jw_00040 asn_id a3001
# name jw_00041 asn_id a3001
# name jw_00042 asn_id a3001
# name jw_00043 asn_id a3001
# name jw_00044 asn_id a3001
# name jw_00045 asn_id a3001
# name jw_00046 asn_id a3001
# name jw_00047 asn_id a3001
# name jw_00048 asn_id a3001
# name jw_00049 asn_id a3001
# name jw_00050 asn_id a3001
# name jw_00051 asn_id a3001
# name jw_00052 asn_id a3001
# name jw_00053 asn_id a3001
# name jw_00054 asn_id a3001
# name jw_00055 asn_id a3001
# name jw_00056 asn_id a3001
# name jw_00057 asn_id a3001
# name jw_00058 asn_id a3001
# name jw_00059 asn_id a3001
# name jw_00060 asn_id a3001
# name jw_00061 asn_id a3001
# name jw_00062 asn_id a3001
# name jw_00063 asn_id a3001
# name jw_00064 asn_id a3001
# name jw_00065 asn_id a3001
# name jw_00066 asn_id a3001
# name jw_00067 asn_id a3001
# name jw_00068 asn_id a3001
# name jw_00069 asn_id a3001
# name jw_00070 asn_id a3001

# %%
asn_discovered = registry_level2_only().Utility.merge_asns(asns_discovered)

# %%
asn_discovered
# Out:
# []

# %%
rules_lv2_all_candidates = registry_level2_only(global_constraints=all_candidates)

# %%
asns_all_candidates, orphaned = generate(pool, rules_lv2_all_candidates)
# Out:
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.

# %%
asns_all_candidates
# Out:
# [{
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00001",
#              "members": [
#                  {
#                      "expname": "jw_00001_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00002",
#              "members": [
#                  {
#                      "expname": "jw_00002_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00003",
#              "members": [
#                  {
#                      "expname": "jw_00003_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00004",
#              "members": [
#                  {
#                      "expname": "jw_00004_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00005",
#              "members": [
#                  {
#                      "expname": "jw_00005_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00006",
#              "members": [
#                  {
#                      "expname": "jw_00006_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00007",
#              "members": [
#                  {
#                      "expname": "jw_00007_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00008",
#              "members": [
#                  {
#                      "expname": "jw_00008_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00009",
#              "members": [
#                  {
#                      "expname": "jw_00009_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00010",
#              "members": [
#                  {
#                      "expname": "jw_00010_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00011",
#              "members": [
#                  {
#                      "expname": "jw_00011_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00012",
#              "members": [
#                  {
#                      "expname": "jw_00012_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00013",
#              "members": [
#                  {
#                      "expname": "jw_00013_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00014",
#              "members": [
#                  {
#                      "expname": "jw_00014_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00015",
#              "members": [
#                  {
#                      "expname": "jw_00015_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00016",
#              "members": [
#                  {
#                      "expname": "jw_00016_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00017",
#              "members": [
#                  {
#                      "expname": "jw_00017_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00018",
#              "members": [
#                  {
#                      "expname": "jw_00018_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00019",
#              "members": [
#                  {
#                      "expname": "jw_00019_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00020",
#              "members": [
#                  {
#                      "expname": "jw_00020_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00021",
#              "members": [
#                  {
#                      "expname": "jw_00021_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00021",
#              "members": [
#                  {
#                      "expname": "jw_00021_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00021",
#              "members": [
#                  {
#                      "expname": "jw_00021_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00022",
#              "members": [
#                  {
#                      "expname": "jw_00022_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00022",
#              "members": [
#                  {
#                      "expname": "jw_00022_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00022",
#              "members": [
#                  {
#                      "expname": "jw_00022_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00023",
#              "members": [
#                  {
#                      "expname": "jw_00023_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00023",
#              "members": [
#                  {
#                      "expname": "jw_00023_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00023",
#              "members": [
#                  {
#                      "expname": "jw_00023_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00024",
#              "members": [
#                  {
#                      "expname": "jw_00024_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00024",
#              "members": [
#                  {
#                      "expname": "jw_00024_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00024",
#              "members": [
#                  {
#                      "expname": "jw_00024_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00025",
#              "members": [
#                  {
#                      "expname": "jw_00025_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00025",
#              "members": [
#                  {
#                      "expname": "jw_00025_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00025",
#              "members": [
#                  {
#                      "expname": "jw_00025_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00026",
#              "members": [
#                  {
#                      "expname": "jw_00026_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00026",
#              "members": [
#                  {
#                      "expname": "jw_00026_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00026",
#              "members": [
#                  {
#                      "expname": "jw_00026_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00027",
#              "members": [
#                  {
#                      "expname": "jw_00027_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00027",
#              "members": [
#                  {
#                      "expname": "jw_00027_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00027",
#              "members": [
#                  {
#                      "expname": "jw_00027_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00028",
#              "members": [
#                  {
#                      "expname": "jw_00028_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00028",
#              "members": [
#                  {
#                      "expname": "jw_00028_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00028",
#              "members": [
#                  {
#                      "expname": "jw_00028_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00029",
#              "members": [
#                  {
#                      "expname": "jw_00029_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00029",
#              "members": [
#                  {
#                      "expname": "jw_00029_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00029",
#              "members": [
#                  {
#                      "expname": "jw_00029_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00030",
#              "members": [
#                  {
#                      "expname": "jw_00030_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00030",
#              "members": [
#                  {
#                      "expname": "jw_00030_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00030",
#              "members": [
#                  {
#                      "expname": "jw_00030_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o004\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o004",
#      "products": [
#          {
#              "name": "jw_00031",
#              "members": [
#                  {
#                      "expname": "jw_00031_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00031",
#              "members": [
#                  {
#                      "expname": "jw_00031_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1001\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1001",
#      "products": [
#          {
#              "name": "jw_00031",
#              "members": [
#                  {
#                      "expname": "jw_00031_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o004\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o004",
#      "products": [
#          {
#              "name": "jw_00032",
#              "members": [
#                  {
#                      "expname": "jw_00032_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1000\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1000",
#      "products": [
#          {
#              "name": "jw_00032",
#              "members": [
#                  {
#                      "expname": "jw_00032_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
# ...
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00061",
#              "members": [
#                  {
#                      "expname": "jw_00061_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00062",
#              "members": [
#                  {
#                      "expname": "jw_00062_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00062",
#              "members": [
#                  {
#                      "expname": "jw_00062_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00063",
#              "members": [
#                  {
#                      "expname": "jw_00063_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00063",
#              "members": [
#                  {
#                      "expname": "jw_00063_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00064",
#              "members": [
#                  {
#                      "expname": "jw_00064_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00064",
#              "members": [
#                  {
#                      "expname": "jw_00064_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00065",
#              "members": [
#                  {
#                      "expname": "jw_00065_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00065",
#              "members": [
#                  {
#                      "expname": "jw_00065_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00066",
#              "members": [
#                  {
#                      "expname": "jw_00066_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00066",
#              "members": [
#                  {
#                      "expname": "jw_00066_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00067",
#              "members": [
#                  {
#                      "expname": "jw_00067_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00067",
#              "members": [
#                  {
#                      "expname": "jw_00067_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00068",
#              "members": [
#                  {
#                      "expname": "jw_00068_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00068",
#              "members": [
#                  {
#                      "expname": "jw_00068_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00069",
#              "members": [
#                  {
#                      "expname": "jw_00069_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00069",
#              "members": [
#                  {
#                      "expname": "jw_00069_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00070",
#              "members": [
#                  {
#                      "expname": "jw_00070_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'c1002\\\\'\\\\,\\\\ \\\\'mosaic\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "c1002",
#      "products": [
#          {
#              "name": "jw_00070",
#              "members": [
#                  {
#                      "expname": "jw_00070_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }]

# %%
for asn in asns_all_candidates:
    print('name {} asn_id {}'.format(asn['products'][0]['name'], asn['asn_id']))
# Out:
# name jw_00001 asn_id o001
# name jw_00002 asn_id o001
# name jw_00003 asn_id o001
# name jw_00004 asn_id o001
# name jw_00005 asn_id o001
# name jw_00006 asn_id o001
# name jw_00007 asn_id o001
# name jw_00008 asn_id o001
# name jw_00009 asn_id o001
# name jw_00010 asn_id o001
# name jw_00011 asn_id o002
# name jw_00012 asn_id o002
# name jw_00013 asn_id o002
# name jw_00014 asn_id o002
# name jw_00015 asn_id o002
# name jw_00016 asn_id o002
# name jw_00017 asn_id o002
# name jw_00018 asn_id o002
# name jw_00019 asn_id o002
# name jw_00020 asn_id o002
# name jw_00021 asn_id o003
# name jw_00021 asn_id c1000
# name jw_00021 asn_id c1001
# name jw_00022 asn_id o003
# name jw_00022 asn_id c1000
# name jw_00022 asn_id c1001
# name jw_00023 asn_id o003
# name jw_00023 asn_id c1000
# name jw_00023 asn_id c1001
# name jw_00024 asn_id o003
# name jw_00024 asn_id c1000
# name jw_00024 asn_id c1001
# name jw_00025 asn_id o003
# name jw_00025 asn_id c1000
# name jw_00025 asn_id c1001
# name jw_00026 asn_id o003
# name jw_00026 asn_id c1000
# name jw_00026 asn_id c1001
# name jw_00027 asn_id o003
# name jw_00027 asn_id c1000
# name jw_00027 asn_id c1001
# name jw_00028 asn_id o003
# name jw_00028 asn_id c1000
# name jw_00028 asn_id c1001
# name jw_00029 asn_id o003
# name jw_00029 asn_id c1000
# name jw_00029 asn_id c1001
# name jw_00030 asn_id o003
# name jw_00030 asn_id c1000
# name jw_00030 asn_id c1001
# name jw_00031 asn_id o004
# name jw_00031 asn_id c1000
# name jw_00031 asn_id c1001
# name jw_00032 asn_id o004
# name jw_00032 asn_id c1000
# name jw_00032 asn_id c1001
# name jw_00033 asn_id o004
# name jw_00033 asn_id c1000
# name jw_00033 asn_id c1001
# name jw_00034 asn_id o004
# name jw_00034 asn_id c1000
# name jw_00034 asn_id c1001
# name jw_00035 asn_id o004
# name jw_00035 asn_id c1000
# name jw_00035 asn_id c1001
# name jw_00036 asn_id o004
# name jw_00036 asn_id c1000
# name jw_00036 asn_id c1001
# name jw_00037 asn_id o004
# name jw_00037 asn_id c1000
# name jw_00037 asn_id c1001
# name jw_00038 asn_id o004
# name jw_00038 asn_id c1000
# name jw_00038 asn_id c1001
# name jw_00039 asn_id o004
# name jw_00039 asn_id c1000
# name jw_00039 asn_id c1001
# name jw_00040 asn_id o004
# name jw_00040 asn_id c1000
# name jw_00040 asn_id c1001
# name jw_00041 asn_id o005
# name jw_00041 asn_id c1001
# name jw_00042 asn_id o005
# name jw_00042 asn_id c1001
# name jw_00043 asn_id o005
# name jw_00043 asn_id c1001
# name jw_00044 asn_id o005
# name jw_00044 asn_id c1001
# name jw_00045 asn_id o005
# name jw_00045 asn_id c1001
# name jw_00046 asn_id o005
# name jw_00046 asn_id c1001
# name jw_00047 asn_id o005
# name jw_00047 asn_id c1001
# name jw_00048 asn_id o005
# name jw_00048 asn_id c1001
# name jw_00049 asn_id o005
# name jw_00049 asn_id c1001
# name jw_00050 asn_id o005
# name jw_00050 asn_id c1001
# name jw_00051 asn_id o006
# name jw_00051 asn_id c1002
# name jw_00052 asn_id o006
# name jw_00052 asn_id c1002
# name jw_00053 asn_id o006
# name jw_00053 asn_id c1002
# name jw_00054 asn_id o006
# name jw_00054 asn_id c1002
# name jw_00055 asn_id o006
# name jw_00055 asn_id c1002
# name jw_00056 asn_id o006
# name jw_00056 asn_id c1002
# name jw_00057 asn_id o006
# name jw_00057 asn_id c1002
# name jw_00058 asn_id o006
# name jw_00058 asn_id c1002
# name jw_00059 asn_id o006
# name jw_00059 asn_id c1002
# name jw_00060 asn_id o006
# name jw_00060 asn_id c1002
# name jw_00061 asn_id o007
# name jw_00061 asn_id c1002
# name jw_00062 asn_id o007
# name jw_00062 asn_id c1002
# name jw_00063 asn_id o007
# name jw_00063 asn_id c1002
# name jw_00064 asn_id o007
# name jw_00064 asn_id c1002
# name jw_00065 asn_id o007
# name jw_00065 asn_id c1002
# name jw_00066 asn_id o007
# name jw_00066 asn_id c1002
# name jw_00067 asn_id o007
# name jw_00067 asn_id c1002
# name jw_00068 asn_id o007
# name jw_00068 asn_id c1002
# name jw_00069 asn_id o007
# name jw_00069 asn_id c1002
# name jw_00070 asn_id o007
# name jw_00070 asn_id c1002

# %%
asn_all_candidates = rules_lv2_all_candidates.Utility.merge_asns(asns_all_candidates)

# %%
asn_all_candidates
# Out:
# [{
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00001",
#              "members": [
#                  {
#                      "expname": "jw_00001_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00002",
#              "members": [
#                  {
#                      "expname": "jw_00002_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00003",
#              "members": [
#                  {
#                      "expname": "jw_00003_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00004",
#              "members": [
#                  {
#                      "expname": "jw_00004_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00005",
#              "members": [
#                  {
#                      "expname": "jw_00005_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00006",
#              "members": [
#                  {
#                      "expname": "jw_00006_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00007",
#              "members": [
#                  {
#                      "expname": "jw_00007_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00008",
#              "members": [
#                  {
#                      "expname": "jw_00008_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00009",
#              "members": [
#                  {
#                      "expname": "jw_00009_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00010",
#              "members": [
#                  {
#                      "expname": "jw_00010_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00011",
#              "members": [
#                  {
#                      "expname": "jw_00011_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00012",
#              "members": [
#                  {
#                      "expname": "jw_00012_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00013",
#              "members": [
#                  {
#                      "expname": "jw_00013_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00014",
#              "members": [
#                  {
#                      "expname": "jw_00014_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00015",
#              "members": [
#                  {
#                      "expname": "jw_00015_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00016",
#              "members": [
#                  {
#                      "expname": "jw_00016_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00017",
#              "members": [
#                  {
#                      "expname": "jw_00017_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00018",
#              "members": [
#                  {
#                      "expname": "jw_00018_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00019",
#              "members": [
#                  {
#                      "expname": "jw_00019_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00020",
#              "members": [
#                  {
#                      "expname": "jw_00020_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o003\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o003",
#      "products": [
#          {
#              "name": "jw_00021",
#              "members": [
#                  {
#                      "expname": "jw_00021_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00022",
#              "members": [
#                  {
#                      "expname": "jw_00022_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00023",
#              "members": [
#                  {
#                      "expname": "jw_00023_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00024",
#              "members": [
#                  {
#                      "expname": "jw_00024_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00025",
#              "members": [
#                  {
#                      "expname": "jw_00025_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00026",
#              "members": [
#                  {
#                      "expname": "jw_00026_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00027",
#              "members": [
#                  {
#                      "expname": "jw_00027_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00028",
#              "members": [
#                  {
#                      "expname": "jw_00028_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00029",
#              "members": [
#                  {
#                      "expname": "jw_00029_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00030",
#              "members": [
#                  {
#                      "expname": "jw_00030_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o004\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o004",
#      "products": [
#          {
#              "name": "jw_00031",
#              "members": [
#                  {
#                      "expname": "jw_00031_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00032",
#              "members": [
#                  {
#                      "expname": "jw_00032_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00033",
#              "members": [
#                  {
#                      "expname": "jw_00033_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00034",
#              "members": [
#                  {
#                      "expname": "jw_00034_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00035",
#              "members": [
#                  {
#                      "expname": "jw_00035_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00036",
#              "members": [
#                  {
#                      "expname": "jw_00036_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00037",
#              "members": [
#                  {
#                      "expname": "jw_00037_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00038",
#              "members": [
#                  {
#                      "expname": "jw_00038_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00039",
#              "members": [
#                  {
#                      "expname": "jw_00039_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00040",
#              "members": [
#                  {
#                      "expname": "jw_00040_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o005\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o005",
#      "products": [
#          {
#              "name": "jw_00041",
#              "members": [
#                  {
#                      "expname": "jw_00041_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00042",
#              "members": [
#                  {
#                      "expname": "jw_00042_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00043",
#              "members": [
#                  {
#                      "expname": "jw_00043_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00044",
#              "members": [
#                  {
#                      "expname": "jw_00044_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00045",
#              "members": [
#                  {
#                      "expname": "jw_00045_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00046",
#              "members": [
#                  {
#                      "expname": "jw_00046_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00047",
#              "members": [
#                  {
#                      "expname": "jw_00047_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00048",
#              "members": [
#                  {
#                      "expname": "jw_00048_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00049",
#              "members": [
#                  {
#                      "expname": "jw_00049_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00050",
#              "members": [
#                  {
#                      "expname": "jw_00050_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o006\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o006",
#      "products": [
#          {
#              "name": "jw_00051",
#              "members": [
#                  {
#                      "expname": "jw_00051_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00052",
#              "members": [
#                  {
#                      "expname": "jw_00052_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00053",
#              "members": [
#                  {
#                      "expname": "jw_00053_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00054",
#              "members": [
#                  {
#                      "expname": "jw_00054_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00055",
#              "members": [
#                  {
#                      "expname": "jw_00055_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00056",
#              "members": [
#                  {
#                      "expname": "jw_00056_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00057",
#              "members": [
#                  {
#                      "expname": "jw_00057_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00058",
#              "members": [
#                  {
#                      "expname": "jw_00058_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00059",
#              "members": [
#                  {
#                      "expname": "jw_00059_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00060",
#              "members": [
#                  {
#                      "expname": "jw_00060_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o007\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o007",
#      "products": [
#          {
#              "name": "jw_00061",
#              "members": [
#                  {
#                      "expname": "jw_00061_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00062",
#              "members": [
#                  {
#                      "expname": "jw_00062_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00063",
#              "members": [
#                  {
#                      "expname": "jw_00063_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00064",
#              "members": [
#                  {
#                      "expname": "jw_00064_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00065",
#              "members": [
#                  {
#                      "expname": "jw_00065_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00066",
#              "members": [
#                  {
#                      "expname": "jw_00066_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00067",
#              "members": [
#                  {
#                      "expname": "jw_00067_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00068",
#              "members": [
#                  {
#                      "expname": "jw_00068_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00069",
#              "members": [
#                  {
#                      "expname": "jw_00069_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00070",
#              "members": [
#                  {
#                      "expname": "jw_00070_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }]

# %%
constrain_1_2 = {
    'asn_candidate': constrain_on_candidates(['o001', 'o002'])
}

# %%
rules_lv2_1_2 = registry_level2_only(global_constraints=constrain_1_2)

# %%
asns_1_2, orphaned = generate(pool, rules_lv2_1_2)
# Out:
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201712051625:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.

# %%
asns_1_2
# Out:
# [{
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00001",
#              "members": [
#                  {
#                      "expname": "jw_00001_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00002",
#              "members": [
#                  {
#                      "expname": "jw_00002_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00003",
#              "members": [
#                  {
#                      "expname": "jw_00003_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00004",
#              "members": [
#                  {
#                      "expname": "jw_00004_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00005",
#              "members": [
#                  {
#                      "expname": "jw_00005_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00006",
#              "members": [
#                  {
#                      "expname": "jw_00006_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00007",
#              "members": [
#                  {
#                      "expname": "jw_00007_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00008",
#              "members": [
#                  {
#                      "expname": "jw_00008_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00009",
#              "members": [
#                  {
#                      "expname": "jw_00009_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00010",
#              "members": [
#                  {
#                      "expname": "jw_00010_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00011",
#              "members": [
#                  {
#                      "expname": "jw_00011_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00012",
#              "members": [
#                  {
#                      "expname": "jw_00012_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00013",
#              "members": [
#                  {
#                      "expname": "jw_00013_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00014",
#              "members": [
#                  {
#                      "expname": "jw_00014_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcalong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00015",
#              "members": [
#                  {
#                      "expname": "jw_00015_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00016",
#              "members": [
#                  {
#                      "expname": "jw_00016_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb2'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00017",
#              "members": [
#                  {
#                      "expname": "jw_00017_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb3'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00018",
#              "members": [
#                  {
#                      "expname": "jw_00018_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcb4'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00019",
#              "members": [
#                  {
#                      "expname": "jw_00019_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrcblong'}\n    opt_elem: {'f277w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00020",
#              "members": [
#                  {
#                      "expname": "jw_00020_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }]

# %%
asn_1_2 = rules_lv2_1_2.Utility.merge_asns(asns_1_2)

# %%
asn_1_2
# Out:
# [{
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00001",
#              "members": [
#                  {
#                      "expname": "jw_00001_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00002",
#              "members": [
#                  {
#                      "expname": "jw_00002_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00003",
#              "members": [
#                  {
#                      "expname": "jw_00003_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00004",
#              "members": [
#                  {
#                      "expname": "jw_00004_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00005",
#              "members": [
#                  {
#                      "expname": "jw_00005_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00006",
#              "members": [
#                  {
#                      "expname": "jw_00006_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00007",
#              "members": [
#                  {
#                      "expname": "jw_00007_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00008",
#              "members": [
#                  {
#                      "expname": "jw_00008_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00009",
#              "members": [
#                  {
#                      "expname": "jw_00009_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00010",
#              "members": [
#                  {
#                      "expname": "jw_00010_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.9.4",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_001_candidates",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nrc_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'nircam'}\n    detector: {'nrca1'}\n    opt_elem: {'f090w'}\n    opt_elem2: {'clear'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o002\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}\n    is_tso: set()",
#      "asn_id": "o002",
#      "products": [
#          {
#              "name": "jw_00011",
#              "members": [
#                  {
#                      "expname": "jw_00011_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00012",
#              "members": [
#                  {
#                      "expname": "jw_00012_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00013",
#              "members": [
#                  {
#                      "expname": "jw_00013_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00014",
#              "members": [
#                  {
#                      "expname": "jw_00014_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00015",
#              "members": [
#                  {
#                      "expname": "jw_00015_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00016",
#              "members": [
#                  {
#                      "expname": "jw_00016_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00017",
#              "members": [
#                  {
#                      "expname": "jw_00017_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00018",
#              "members": [
#                  {
#                      "expname": "jw_00018_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00019",
#              "members": [
#                  {
#                      "expname": "jw_00019_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00020",
#              "members": [
#                  {
#                      "expname": "jw_00020_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }]

# %%
asn_name, serialized = asn_1_2[0].dump()

# %%
asn_name
# Out:
# 'jw99009-o001_image2_212_asn'

# %% [markdown]
# ## All Candidates issue

# %%
len(pool)

# %%
pdb.run("Main("
    "pool=pool,"
    "args=["
    "    '--dry-run',"
    "    '--ignore-default',"
    "    '-r',"
    "    '/Users/eisenham/Documents/ssbdev/jwst/jwst/associations/lib/rules_level2b.py',"
    "    '-v',"
    "    '--all-candidates',"
    "]"
")")

# %%
generated = Main(
    pool=pool,
    args=[
        '--dry-run',
        '--ignore-default',
        '-r',
        '/Users/eisenham/Documents/ssbdev/jwst/jwst/associations/lib/rules_level2b.py',
        '-v',
        '--all-candidates',
    ]
)

# %%
# %debug

# %%
rules = AssociationRegistry(global_constraints=all_candidates)
rules_lv2 = registry_level2_only(global_constraints=all_candidates)
rules_lv3 = registry_level3_only(global_constraints=all_candidates)

# %%
asns, orphaned = generate(pool, rules_lv2)

# %%
pdb.run("generate(pool, rules_lv2)")

# %%
len(asns)

# %%
asn = asns[0]

# %%
asn.__str__()
