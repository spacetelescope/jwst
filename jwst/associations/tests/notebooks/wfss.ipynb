# %% [markdown]
# # Abstract

# %% [markdown]
# Develop and test WFSS associations

# %% [markdown]
# # Environment

# %%
# Setup debugging log
import logging
logger = logging.getLogger('jwst.associations')
handler = logging.StreamHandler()
logger.addHandler(handler)
handler.setLevel(logging.DEBUG)
logger.setLevel(logging.DEBUG)

# %%
from jwst.associations import (
    AssociationRegistry,
    generate
)
from jwst.associations.main import Main

# %%
from jwst.associations.tests.helpers import (
    combine_pools,
    registry_level3_only,
    registry_level2_only,
    t_path,
)

# %% [markdown]
# # Library

# %% [markdown]
# # Main

# %% [markdown]
# ## Basic Main run

# %%
args_basic = [
    '--dry-run',
    '-D'
]

# %%
pool = combine_pools('../data/pool_019_niriss_wfss.csv')

# %%
main_basic = Main(
    args_basic,
    pool=pool
)
# Out:
# Command-line arguments: ['--dry-run', '-D']
# Reading rules.
# Generating associations.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level2_base.rename_to_level2a:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2a.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:WARNING:jwst.associations.lib.rules_level3_base.rename_to_level2b:Item FILENAME="set acid" is not a Level 1b name. Cannot transform to Level 2b.
# 201709211418:DEBUG:jwst.associations.__init__:# asns found before discover filtering=36
# There where 4 associations and 2 orphaned items found.
# Associations found are:
# jw99009-o001_image3_001_asn with 1 products
# Rule=candidate_Asn_Image
# Constraints:
#     wfsvisit: Is Invalid
#     exp_type: {'nis_image'}
#     opt_elem: {'f140m'}
#     opt_elem2: set()
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'niriss'}
#     asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o001_t001_niriss_f140m with 4 members
# jw99009-o001_spec3_001_asn with 1 products
# Rule=candidate_Asn_WFSS
# Constraints:
#     exp_type: {'nis_wfss'}
#     opt_elem2: {'gr150c', 'gr150r'}
#     opt_elem: {'f140m'}
#     target: {'1'}
#     program: {'99009'}
#     instrument: {'niriss'}
#     asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
# Products:
# 	jw99009-o001_t001_niriss_f140m-gr150c-gr150r with 12 members
# Association jw99009-o001_image2_001_asn
#     Parameters:
#         Product type: image2
#         Rule:         candidate_Asn_Lv2Image
#         Program:      99009
#         Target:       1
#         Pool:         pool_019_niriss_wfss
#         Constraints:
#             single_science: {'False'}
#             exp_type: {'nis_image'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'niriss'}
#             detector: {'central'}
#             opt_elem: {'f140m'}
#             opt_elem2: set()
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
# 	jw_00001 with 1 members
# 	jw_00008 with 1 members
# 	jw_00009 with 1 members
# 	jw_00016 with 1 members
#
#
# Association jw99009-o001_spec2_001_asn
#     Parameters:
#         Product type: spec2
#         Rule:         candidate_Asn_Lv2WFSS
#         Program:      99009
#         Target:       1
#         Pool:         pool_019_niriss_wfss
#         Constraints:
#             exp_type: {'nis_wfss'}
#             single_science: {'False'}
#             program: {'99009'}
#             target: {'1'}
#             instrument: {'niriss'}
#             detector: {'central'}
#             opt_elem: {'f140m'}
#             opt_elem2: {'gr150r'}
#             subarray: set()
#             channel: set()
#             asn_candidate: {"\\(\\'o001\\'\\,\\ \\'observation\\'\\)"}
# 	jw_00002 with 2 members
# 	jw_00003 with 2 members
# 	jw_00004 with 2 members
# 	jw_00005 with 2 members
# 	jw_00006 with 2 members
# 	jw_00007 with 2 members
# 	jw_00010 with 2 members
# 	jw_00011 with 2 members
# 	jw_00012 with 2 members
# 	jw_00013 with 2 members
# 	jw_00014 with 2 members
# 	jw_00015 with 2 members

# %%
main_basic.associations
# Out:
# [{
#      "asn_type": "image3",
#      "asn_rule": "candidate_Asn_Image",
#      "version_id": null,
#      "code_version": "0.7.1.beta5",
#      "program": "99009",
#      "degraded_status": "No known degraded exposures in association.",
#      "constraints": "Constraints:\n    wfsvisit: Is Invalid\n    exp_type: {'nis_image'}\n    opt_elem: {'f140m'}\n    opt_elem2: set()\n    target: {'1'}\n    program: {'99009'}\n    instrument: {'niriss'}\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}",
#      "asn_id": "o001",
#      "target": "t001",
#      "asn_pool": "pool_019_niriss_wfss",
#      "products": [
#          {
#              "name": "jw99009-o001_t001_niriss_f140m",
#              "members": [
#                  {
#                      "expname": "jw_00001_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00008_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00009_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00016_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "spec3",
#      "asn_rule": "candidate_Asn_WFSS",
#      "version_id": null,
#      "code_version": "0.7.1.beta5",
#      "program": "99009",
#      "degraded_status": "No known degraded exposures in association.",
#      "constraints": "Constraints:\n    exp_type: {'nis_wfss'}\n    opt_elem2: {'gr150c', 'gr150r'}\n    opt_elem: {'f140m'}\n    target: {'1'}\n    program: {'99009'}\n    instrument: {'niriss'}\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}",
#      "asn_id": "o001",
#      "target": "t001",
#      "asn_pool": "pool_019_niriss_wfss",
#      "products": [
#          {
#              "name": "jw99009-o001_t001_niriss_f140m-gr150c-gr150r",
#              "members": [
#                  {
#                      "expname": "jw_00002_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00003_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00004_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00005_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00006_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00007_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00010_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00011_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00012_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00013_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00014_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  },
#                  {
#                      "expname": "jw_00015_cal.fits",
#                      "exptype": "science",
#                      "exposerr": null,
#                      "asn_candidate": "('o001', 'observation')"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "image2",
#      "asn_rule": "candidate_Asn_Lv2Image",
#      "version_id": null,
#      "code_version": "0.7.1.beta5",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_019_niriss_wfss",
#      "constraints": "Constraints:\n    single_science: {'False'}\n    exp_type: {'nis_image'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'niriss'}\n    detector: {'central'}\n    opt_elem: {'f140m'}\n    opt_elem2: set()\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00001",
#              "members": [
#                  {
#                      "expname": "jw_00001_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00008",
#              "members": [
#                  {
#                      "expname": "jw_00008_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00009",
#              "members": [
#                  {
#                      "expname": "jw_00009_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00016",
#              "members": [
#                  {
#                      "expname": "jw_00016_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }, {
#      "asn_type": "spec2",
#      "asn_rule": "candidate_Asn_Lv2WFSS",
#      "version_id": null,
#      "code_version": "0.7.1.beta5",
#      "program": "99009",
#      "target": "1",
#      "asn_pool": "pool_019_niriss_wfss",
#      "constraints": "Constraints:\n    exp_type: {'nis_wfss'}\n    single_science: {'False'}\n    program: {'99009'}\n    target: {'1'}\n    instrument: {'niriss'}\n    detector: {'central'}\n    opt_elem: {'f140m'}\n    opt_elem2: {'gr150r'}\n    subarray: set()\n    channel: set()\n    asn_candidate: {\"\\\\(\\\\'o001\\\\'\\\\,\\\\ \\\\'observation\\\\'\\\\)\"}",
#      "asn_id": "o001",
#      "products": [
#          {
#              "name": "jw_00002",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00002_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00003",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00003_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00004",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00004_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00005",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00005_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00006",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00006_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00007",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00007_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00010",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00010_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00011",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00011_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00012",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00012_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00013",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00013_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00014",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00014_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          },
#          {
#              "name": "jw_00015",
#              "members": [
#                  {
#                      "expname": "jw99009-o001_t001_niriss_f140m.ecsv",
#                      "exptype": "catalog"
#                  },
#                  {
#                      "expname": "jw_00015_rate.fits",
#                      "exptype": "science"
#                  }
#              ]
#          }
#      ]
#  }]
