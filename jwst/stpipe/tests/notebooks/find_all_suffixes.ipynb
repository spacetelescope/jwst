# %% [markdown]
# # Abstract

# %% [markdown]
# Read through a folder, importing everything, to do some basic searching about.

# %% [markdown]
# # Environment

# %%
from copy import copy
from importlib import import_module
from inspect import (getmembers, isclass)
import logging
from os import (listdir, path, walk)
import re
import sys

# %%
from jwst.stpipe import Step

# %%
SUFFIXES_TO_DISCARD = set(('functionwrapper', 'systemcall'))

# %%
SUFFIXES_TO_ADD = set((
    'cal', 'calints', 'crf', 'crfints',
    'dark',
    'i2d',
    'jump',
    'psfalign', 'psfstack', 'psfsub',
    'ramp', 'rate', 'rateints',
    's2d', 's3d',
    'uncal',
    'wfscmb',
    'x1d', 'x1dints',
))

# %% [markdown]
# # Library

# %%
def folder_traverse(folder_path, basename_regex='.+', path_exclude_regex='^$'):
    """Generator of full file paths for all files
    in a folder.
    
    Parameters
    ----------
    folder_path: str
        The folder to traverse
        
    basename_regex: str
        Regular expression that must match
        the `basename` part of the file path.
        
    path_exclude_regex: str
        Regular expression to exclude a path.
        
    Returns
    -------
    generator
        A generator, return the next file.
    """
    basename_regex = re.compile(basename_regex)
    path_exclude_regex = re.compile(path_exclude_regex)
    for root, dirs, files in walk(folder_path):
        if path_exclude_regex.search(root):
            continue
        for file in files:
            if basename_regex.match(file):
                yield path.join(root, file)

# %%
def load_local_pkg(fpath):
    """Generator producing all modules under fpath
    """
    package_fpath, package = path.split(fpath)
    package_fpath_len = len(package_fpath) + 1
    sys_path = copy(sys.path)
    sys.path.insert(0, package_fpath)
    try:
        for module_fpath in folder_traverse(
            fpath, basename_regex='[^_].+\.py$', path_exclude_regex='tests'
        ):
            folder_path, fname = path.split(module_fpath[package_fpath_len:])
            module_path = folder_path.split('/')
            module_path.append(path.splitext(fname)[0])
            module_path = '.'.join(module_path)
            try:
                module = import_module(module_path)
            except Exception:
                logging.warning('Cannot load module "{}"'.format(module_path))
            else:
                yield module
    except Exception as exception:
        logging.warning('Exception occurred: "{}'.format(exception))
    finally:
        sys.path = sys_path

# %%
def find_suffixes():
    """Find all possible suffixes from the jwst package
    
    Returns
    -------
    suffixes: set
        The set of all programmatically findable suffixes.
        
    Notes
    -----
    This will load all of the `jwst` package. Consider if this
    is worth doing dynamically or only as a utility to update
    a static list.
    """
    suffixes = set()
    
    jwst = import_module('jwst')
    jwst_fpath = path.split(jwst.__file__)[0]
    
    # First traverse the code base and find all
    # `Step` classes. The default suffix is the
    # class name.
    for module in load_local_pkg(jwst_fpath):
        for klass_name, klass in getmembers(
            module,
            lambda o: isclass(o) and issubclass(o, Step)
        ):
            suffixes.add(klass_name.lower())
            
    # Instantiate Steps/Pipelines from their configuration files.
    # Different names and suffixes can be defined in this way.
    # Note: Based on the `collect_pipeline_cfgs` script
    config_path = path.join(jwst_fpath, 'pipeline') 
    for config_file in listdir(config_path):
        if config_file.endswith('.cfg'):
            try:
                step = Step.from_config_file(path.join(config_path, config_file))
            except Exception as exception:
                pass
            else:
                suffixes.add(step.name.lower())
                if step.suffix is not None:
                    suffixes.add(step.suffix.lower())
                    
    # Discard known bad finds.
    suffixes.difference_update(SUFFIXES_TO_DISCARD)
    
    # Add defined suffixes
    suffixes.update(SUFFIXES_TO_ADD)
                    
    # That's all folks
    return suffixes

# %% [markdown]
# # Main

# %%
re.search('^$', '/Users/eisenham/Documents/ssbdev/jwst/jwst/associations/notebooks')

# %%
jwst = import_module('jwst')
jwst.__file__
# Out:
# '/Users/eisenham/Documents/ssbdev/jwst/jwst/__init__.py'

# %% [markdown]
# ## Setup the all-in-one function

# %%
suffixes_from_find = find_suffixes()
# Out:
# 2018-04-06 13:55:20,615 - stpipe - WARNING - Cannot load module "jwst.cube_build.CubeD2C"
# 2018-04-06 13:55:20,643 - stpipe - WARNING - Cannot load module "jwst.lib.convert_to_uncal"
# 2018-04-06 13:55:20,653 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.mc_2d"
# 2018-04-06 13:55:20,656 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.mc_3d"
# 2018-04-06 13:55:20,658 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.rotate_dataset"
# 2018-04-06 13:55:20,660 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.rotate_utils"
# 2018-04-06 13:55:20,667 - stpipe.alignrefs - INFO - AlignRefsStep instance created.
# 2018-04-06 13:55:20,669 - stpipe.ami_analyze - INFO - AmiAnalyzeStep instance created.
# 2018-04-06 13:55:20,671 - stpipe.ami_average - INFO - AmiAverageStep instance created.
# 2018-04-06 13:55:20,674 - stpipe.ami_normalize - INFO - AmiNormalizeStep instance created.
# 2018-04-06 13:55:20,676 - stpipe.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:55:20,678 - stpipe.background - INFO - BackgroundStep instance created.
# 2018-04-06 13:55:20,682 - stpipe.Ami3Pipeline - INFO - Ami3Pipeline instance created.
# 2018-04-06 13:55:20,683 - stpipe.Ami3Pipeline.ami_analyze - INFO - AmiAnalyzeStep instance created.
# 2018-04-06 13:55:20,685 - stpipe.Ami3Pipeline.ami_average - INFO - AmiAverageStep instance created.
# 2018-04-06 13:55:20,686 - stpipe.Ami3Pipeline.ami_normalize - INFO - AmiNormalizeStep instance created.
# 2018-04-06 13:55:20,691 - stpipe.Coron3Pipeline - INFO - Coron3Pipeline instance created.
# 2018-04-06 13:55:20,692 - stpipe.Coron3Pipeline.stack_refs - INFO - StackRefsStep instance created.
# 2018-04-06 13:55:20,694 - stpipe.Coron3Pipeline.align_refs - INFO - AlignRefsStep instance created.
# 2018-04-06 13:55:20,695 - stpipe.Coron3Pipeline.klip - INFO - KlipStep instance created.
# 2018-04-06 13:55:20,697 - stpipe.Coron3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:55:20,699 - stpipe.Coron3Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:55:20,709 - stpipe.DarkPipeline - INFO - DarkPipeline instance created.
# 2018-04-06 13:55:20,710 - stpipe.DarkPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:55:20,711 - stpipe.DarkPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:55:20,712 - stpipe.DarkPipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:55:20,713 - stpipe.DarkPipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:55:20,715 - stpipe.DarkPipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:55:20,717 - stpipe.DarkPipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:55:20,718 - stpipe.DarkPipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:55:20,720 - stpipe.DarkPipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:55:20,721 - stpipe.DarkPipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:55:20,734 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-06 13:55:20,735 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:55:20,737 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:55:20,738 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:55:20,739 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:55:20,741 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:55:20,742 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:55:20,743 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:55:20,744 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:55:20,746 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:55:20,747 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:55:20,748 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:55:20,750 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:55:20,752 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-06 13:55:20,753 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-06 13:55:20,754 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:55:20,760 - stpipe.GuiderPipeline - INFO - GuiderPipeline instance created.
# 2018-04-06 13:55:20,761 - stpipe.GuiderPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:55:20,763 - stpipe.GuiderPipeline.guider_cds - INFO - GuiderCdsStep instance created.
# 2018-04-06 13:55:20,764 - stpipe.GuiderPipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:55:20,772 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2018-04-06 13:55:20,774 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-06 13:55:20,775 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:55:20,776 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:55:20,777 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:55:20,778 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:55:20,788 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2018-04-06 13:55:20,790 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2018-04-06 13:55:20,791 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2018-04-06 13:55:20,793 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:55:20,794 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:55:20,796 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2018-04-06 13:55:20,806 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-06 13:55:20,808 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-06 13:55:20,809 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:55:20,810 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-06 13:55:20,811 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-06 13:55:20,812 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-06 13:55:20,814 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:55:20,815 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-06 13:55:20,816 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-06 13:55:20,817 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-06 13:55:20,818 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-06 13:55:20,819 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-06 13:55:20,821 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:55:20,823 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:55:20,825 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:55:20,827 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:55:20,832 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2018-04-06 13:55:20,834 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2018-04-06 13:55:20,835 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:55:20,837 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:55:20,839 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:55:20,840 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:55:20,850 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-06 13:55:20,852 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:55:20,854 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:55:20,855 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:55:20,857 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:55:20,859 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:55:20,860 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:55:20,861 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:55:20,863 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:55:20,864 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:55:20,865 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:55:20,866 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:55:20,868 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:55:20,869 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-06 13:55:20,870 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-06 13:55:20,871 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:55:20,879 - stpipe.Tso3Pipeline - INFO - Tso3Pipeline instance created.
# 2018-04-06 13:55:20,880 - stpipe.Tso3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:55:20,882 - stpipe.Tso3Pipeline.tso_photometry - INFO - TSOPhotometryStep instance created.
# 2018-04-06 13:55:20,883 - stpipe.Tso3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:55:20,884 - stpipe.Tso3Pipeline.white_light - INFO - WhiteLightStep instance created.
# 2018-04-06 13:55:20,886 - stpipe.combine_1d - INFO - Combine1dStep instance created.
# 2018-04-06 13:55:20,888 - stpipe.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:55:20,891 - stpipe.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:55:20,893 - stpipe.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:55:20,894 - stpipe.emission - INFO - EmissionStep instance created.
# 2018-04-06 13:55:20,896 - stpipe.engdblog - INFO - EngDBLogStep instance created.
# 2018-04-06 13:55:20,898 - stpipe.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:55:20,901 - stpipe.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-06 13:55:20,902 - stpipe.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:55:20,904 - stpipe.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:55:20,906 - stpipe.fringe - INFO - FringeStep instance created.
# 2018-04-06 13:55:20,909 - stpipe.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:55:20,910 - stpipe.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:55:20,912 - stpipe.GuiderCDS - INFO - GuiderCdsStep instance created.
# 2018-04-06 13:55:20,914 - stpipe.hlsp - INFO - HlspStep instance created.
# 2018-04-06 13:55:20,915 - stpipe.imprint - INFO - ImprintStep instance created.
# 2018-04-06 13:55:20,917 - stpipe.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:55:20,919 - stpipe.jump - INFO - JumpStep instance created.
# 2018-04-06 13:55:20,921 - stpipe.klip - INFO - KlipStep instance created.
# 2018-04-06 13:55:20,922 - stpipe.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:55:20,932 - stpipe.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:55:20,934 - stpipe.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2018-04-06 13:55:20,936 - stpipe.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:55:20,939 - stpipe.outlier_detection_scaled - INFO - OutlierDetectionScaledStep instance created.
# 2018-04-06 13:55:20,944 - stpipe.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:55:20,946 - stpipe.pathloss - INFO - PathLossStep instance created.
# 2018-04-06 13:55:20,948 - stpipe.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:55:20,951 - stpipe.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:55:20,953 - stpipe.RampFit - INFO - RampFitStep instance created.
# 2018-04-06 13:55:20,956 - stpipe.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:55:20,959 - stpipe.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:55:20,961 - stpipe.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:55:20,963 - stpipe.reset - INFO - ResetStep instance created.
# 2018-04-06 13:55:20,965 - stpipe.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:55:20,967 - stpipe.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:55:20,970 - stpipe.skymatch - INFO - SkyMatchStep instance created.
# 2018-04-06 13:55:20,972 - stpipe.source_catalog - INFO - SourceCatalogStep instance created.
# 2018-04-06 13:55:20,974 - stpipe.srctype - INFO - SourceTypeStep instance created.
# 2018-04-06 13:55:20,975 - stpipe.stackrefs - INFO - StackRefsStep instance created.
# 2018-04-06 13:55:20,976 - stpipe.straylight - INFO - StraylightStep instance created.
# 2018-04-06 13:55:20,978 - stpipe.subtract_images - INFO - SubtractImagesStep instance created.
# 2018-04-06 13:55:20,979 - stpipe.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:55:20,981 - stpipe.tweakreg - INFO - TweakRegStep instance created.
# 2018-04-06 13:55:20,985 - stpipe.WfsCombine - INFO - WfsCombineStep instance created.
# 2018-04-06 13:55:20,987 - stpipe.white_light - INFO - WhiteLightStep instance created.

# %%
len(suffixes_from_find)
# Out:
# 137

# %%
suffixes_from_find
# Out:
# {'alignrefs',
#  'alignrefsstep',
#  'ami3pipeline',
#  'ami_analyze',
#  'ami_average',
#  'ami_normalize',
#  'amianalyzestep',
#  'amiaveragestep',
#  'aminormalizestep',
#  'assign_wcs',
#  'assignwcsstep',
#  'background',
#  'backgroundstep',
#  'barshadowstep',
#  'cal',
#  'calints',
#  'combine1dstep',
#  'combine_1d',
#  'coron3pipeline',
#  'crf',
#  'crfints',
#  'cube_build',
#  'cubebuildstep',
#  'cubeskymatchstep',
#  'dark',
#  'dark_current',
#  'darkcurrentstep',
#  'darkpipeline',
#  'detector1pipeline',
#  'dq_init',
#  'dqinitstep',
#  'emission',
#  'emissionstep',
#  'engdblog',
#  'engdblogstep',
#  'extract1dstep',
#  'extract2dstep',
#  'extract_1d',
#  'extract_2d',
#  'firstframe',
#  'firstframestep',
#  'flat_field',
#  'flatfieldstep',
#  'fringe',
#  'fringestep',
#  'gain_scale',
#  'gainscalestep',
#  'group_scale',
#  'groupscalestep',
#  'guidercds',
#  'guidercdsstep',
#  'guiderpipeline',
#  'hlsp',
#  'hlspstep',
#  'i2d',
#  'image2pipeline',
#  'image3pipeline',
#  'imprint',
#  'imprintstep',
#  'ipc',
#  'ipcstep',
#  'jump',
#  'jumpstep',
#  'klip',
#  'klipstep',
#  'lastframe',
#  'lastframestep',
#  'linearity',
#  'linearitystep',
#  'linearpipeline',
#  'mrs_imatch',
#  'mrsimatchstep',
#  'msaflagopenstep',
#  'outlier_detection',
#  'outlier_detection_scaled',
#  'outlierdetectionscaledstep',
#  'outlierdetectionstackstep',
#  'outlierdetectionstep',
#  'pathloss',
#  'pathlossstep',
#  'persistence',
#  'persistencestep',
#  'photom',
#  'photomstep',
#  'pipeline',
#  'psfalign',
#  'psfstack',
#  'psfsub',
#  'ramp',
#  'rampfit',
#  'rampfitstep',
#  'rate',
#  'rateints',
#  'refpix',
#  'refpixstep',
#  'resample',
#  'resample_spec',
#  'resamplespecstep',
#  'resamplestep',
#  'reset',
#  'resetstep',
#  'rscd',
#  'rscd_step',
#  's2d',
#  's3d',
#  'saturation',
#  'saturationstep',
#  'skymatch',
#  'skymatchstep',
#  'source_catalog',
#  'sourcecatalogstep',
#  'sourcetypestep',
#  'spec2pipeline',
#  'spec3pipeline',
#  'srctype',
#  'stackrefs',
#  'stackrefsstep',
#  'step',
#  'straylight',
#  'straylightstep',
#  'subtract_images',
#  'subtractimagesstep',
#  'superbias',
#  'superbiasstep',
#  'testlinearpipeline',
#  'tso3pipeline',
#  'tsophotometrystep',
#  'tweakreg',
#  'tweakregstep',
#  'uncal',
#  'wfscmb',
#  'wfscombine',
#  'wfscombinestep',
#  'white_light',
#  'whitelightstep',
#  'x1d',
#  'x1dints'}

# %% [markdown]
# ## The piecemeal developement

# %%
package_location = '../../../../jwst'

# %%
# %ls $package_location
# Out:
# __init__.py        emission/          lib/               source_catalog/
# __init__.pyc       engdblog/          linearity/         srctype/
# __pycache__/       exp_to_source/     model_blender/     steps.py
# ami/               extract_1d/        mrs_imatch/        stpipe/
# assign_wcs/        extract_2d/        msaflagopen/       straylight/
# associations/      firstframe/        outlier_detection/ superbias/
# background/        fits_generator/    pathloss/          tests/
# barshadow/         flatfield/         persistence/       timeconversion/
# cal_ver_steps.py   fringe/            photom/            transforms/
# combine_1d/        gain_scale/        pipeline/          tso_photometry/
# coron/             group_scale/       ramp_fitting/      tweakreg/
# csv_tools/         guider_cds/        refpix/            tweakreg_catalog/
# cube_build/        imprint/           resample/          version.py
# cube_skymatch/     ipc/               reset/             version.pyc
# dark_current/      jump/              rscd/              wfs_combine/
# datamodels/        jwpsf/             saturation/        white_light/
# dq_init/           lastframe/         skymatch/          wiimatch/

# %% [markdown]
# ## Start collecting all possible suffixes

# %%
suffixes = set()

# %% [markdown]
# ## First, find all Step classes
# `Step` class names are the default suffix for any `Step`

# %%
modules = list(load_local_pkg(package_location))
# Out:
# root="../../../../jwst"
# root="../../../../jwst/__pycache__"
# root="../../../../jwst/ami"
# root="../../../../jwst/ami/__pycache__"
# root="../../../../jwst/assign_wcs"
# root="../../../../jwst/assign_wcs/__pycache__"
# root="../../../../jwst/assign_wcs/tests"
# 	****rejected
# root="../../../../jwst/assign_wcs/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/assign_wcs/tests/data"
# 	****rejected
# root="../../../../jwst/assign_wcs/tests/data/__pycache__"
# 	****rejected
# root="../../../../jwst/assign_wcs/tools"
# root="../../../../jwst/assign_wcs/tools/__pycache__"
# root="../../../../jwst/assign_wcs/tools/miri"
# root="../../../../jwst/assign_wcs/tools/miri/__pycache__"
# root="../../../../jwst/assign_wcs/tools/nirspec"
# root="../../../../jwst/assign_wcs/tools/nirspec/__pycache__"
# root="../../../../jwst/associations"
# root="../../../../jwst/associations/__pycache__"
# root="../../../../jwst/associations/lib"
# 2018-04-06 13:10:34,842 - stpipe - WARNING - Cannot load module "jwst.cube_build.CubeD2C"
# 2018-04-06 13:10:34,890 - stpipe - WARNING - Cannot load module "jwst.lib.convert_to_uncal"
# 2018-04-06 13:10:34,905 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.mc_2d"
# 2018-04-06 13:10:34,907 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.mc_3d"
# 2018-04-06 13:10:34,909 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.rotate_dataset"
# 2018-04-06 13:10:34,911 - stpipe - WARNING - Cannot load module "jwst.ramp_fitting.rotate_utils"
# root="../../../../jwst/associations/lib/__pycache__"
# root="../../../../jwst/associations/tests"
# 	****rejected
# root="../../../../jwst/associations/tests/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/associations/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/associations/tests/data"
# 	****rejected
# root="../../../../jwst/associations/tests/data/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/associations/tests/data/__pycache__"
# 	****rejected
# root="../../../../jwst/associations/tests/data/asn_standards"
# 	****rejected
# root="../../../../jwst/associations/tests/data/exposures"
# 	****rejected
# root="../../../../jwst/associations/tests/data/new_asn_standards"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp/asns"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp/new_asns"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp/pool_src"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp/pool_src/build71"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp/pools"
# 	****rejected
# root="../../../../jwst/associations/tests/data/sdp/test"
# 	****rejected
# root="../../../../jwst/associations/tests/notebooks"
# 	****rejected
# root="../../../../jwst/associations/tests/notebooks/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/background"
# root="../../../../jwst/background/__pycache__"
# root="../../../../jwst/barshadow"
# root="../../../../jwst/barshadow/__pycache__"
# root="../../../../jwst/combine_1d"
# root="../../../../jwst/combine_1d/__pycache__"
# root="../../../../jwst/coron"
# root="../../../../jwst/coron/__pycache__"
# root="../../../../jwst/csv_tools"
# root="../../../../jwst/csv_tools/__pycache__"
# root="../../../../jwst/csv_tools/tests"
# 	****rejected
# root="../../../../jwst/csv_tools/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/csv_tools/tests/data"
# 	****rejected
# root="../../../../jwst/csv_tools/tests/data/__pycache__"
# 	****rejected
# root="../../../../jwst/cube_build"
# root="../../../../jwst/cube_build/__pycache__"
# root="../../../../jwst/cube_skymatch"
# root="../../../../jwst/cube_skymatch/__pycache__"
# root="../../../../jwst/dark_current"
# root="../../../../jwst/dark_current/__pycache__"
# root="../../../../jwst/datamodels"
# root="../../../../jwst/datamodels/__pycache__"
# root="../../../../jwst/datamodels/metaschema"
# root="../../../../jwst/datamodels/metaschema/__pycache__"
# root="../../../../jwst/datamodels/schemas"
# root="../../../../jwst/datamodels/schemas/__pycache__"
# root="../../../../jwst/datamodels/tests"
# 	****rejected
# root="../../../../jwst/datamodels/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/datamodels/tests/data"
# 	****rejected
# root="../../../../jwst/dq_init"
# root="../../../../jwst/dq_init/__pycache__"
# root="../../../../jwst/emission"
# root="../../../../jwst/emission/__pycache__"
# root="../../../../jwst/engdblog"
# root="../../../../jwst/engdblog/__pycache__"
# root="../../../../jwst/engdblog/tests"
# 	****rejected
# root="../../../../jwst/engdblog/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/exp_to_source"
# root="../../../../jwst/exp_to_source/__pycache__"
# root="../../../../jwst/exp_to_source/tests"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/data"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/data/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/data/sources"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/data/sources/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/dev"
# 	****rejected
# root="../../../../jwst/exp_to_source/tests/dev/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/extract_1d"
# root="../../../../jwst/extract_1d/__pycache__"
# root="../../../../jwst/extract_2d"
# root="../../../../jwst/extract_2d/__pycache__"
# root="../../../../jwst/firstframe"
# root="../../../../jwst/firstframe/__pycache__"
# root="../../../../jwst/firstframe/tests"
# 	****rejected
# root="../../../../jwst/firstframe/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/fits_generator"
# root="../../../../jwst/fits_generator/__pycache__"
# root="../../../../jwst/fits_generator/templates"
# root="../../../../jwst/fits_generator/templates/__pycache__"
# root="../../../../jwst/flatfield"
# root="../../../../jwst/flatfield/__pycache__"
# root="../../../../jwst/fringe"
# root="../../../../jwst/fringe/__pycache__"
# root="../../../../jwst/gain_scale"
# root="../../../../jwst/gain_scale/__pycache__"
# root="../../../../jwst/group_scale"
# root="../../../../jwst/group_scale/__pycache__"
# root="../../../../jwst/guider_cds"
# root="../../../../jwst/guider_cds/__pycache__"
# root="../../../../jwst/imprint"
# root="../../../../jwst/imprint/__pycache__"
# root="../../../../jwst/ipc"
# root="../../../../jwst/ipc/__pycache__"
# root="../../../../jwst/jump"
# root="../../../../jwst/jump/__pycache__"
# root="../../../../jwst/jump/tests"
# 	****rejected
# root="../../../../jwst/jump/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/jwpsf"
# root="../../../../jwst/jwpsf/__pycache__"
# root="../../../../jwst/lastframe"
# root="../../../../jwst/lastframe/__pycache__"
# root="../../../../jwst/lib"
# root="../../../../jwst/lib/__pycache__"
# root="../../../../jwst/lib/tests"
# 	****rejected
# root="../../../../jwst/lib/tests/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/lib/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/lib/tests/data"
# 	****rejected
# root="../../../../jwst/lib/tests/engdb"
# 	****rejected
# root="../../../../jwst/linearity"
# root="../../../../jwst/linearity/__pycache__"
# root="../../../../jwst/model_blender"
# root="../../../../jwst/model_blender/__pycache__"
# root="../../../../jwst/model_blender/tests"
# 	****rejected
# root="../../../../jwst/model_blender/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/mrs_imatch"
# root="../../../../jwst/mrs_imatch/__pycache__"
# root="../../../../jwst/msaflagopen"
# root="../../../../jwst/msaflagopen/__pycache__"
# root="../../../../jwst/outlier_detection"
# root="../../../../jwst/outlier_detection/__pycache__"
# root="../../../../jwst/pathloss"
# root="../../../../jwst/pathloss/__pycache__"
# root="../../../../jwst/persistence"
# root="../../../../jwst/persistence/__pycache__"
# root="../../../../jwst/photom"
# root="../../../../jwst/photom/__pycache__"
# root="../../../../jwst/pipeline"
# root="../../../../jwst/pipeline/__pycache__"
# root="../../../../jwst/pipeline/tests"
# 	****rejected
# root="../../../../jwst/pipeline/tests/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/pipeline/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/pipeline/tests/data"
# 	****rejected
# root="../../../../jwst/pipeline/tests/data/cfgs"
# 	****rejected
# root="../../../../jwst/pipeline/tests/notebooks"
# 	****rejected
# root="../../../../jwst/pipeline/tests/notebooks/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/ramp_fitting"
# root="../../../../jwst/ramp_fitting/__pycache__"
# root="../../../../jwst/refpix"
# root="../../../../jwst/refpix/__pycache__"
# root="../../../../jwst/resample"
# root="../../../../jwst/resample/__pycache__"
# root="../../../../jwst/resample/tests"
# 	****rejected
# root="../../../../jwst/resample/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/reset"
# root="../../../../jwst/reset/__pycache__"
# root="../../../../jwst/rscd"
# root="../../../../jwst/rscd/__pycache__"
# root="../../../../jwst/saturation"
# root="../../../../jwst/saturation/__pycache__"
# root="../../../../jwst/skymatch"
# root="../../../../jwst/skymatch/__pycache__"
# root="../../../../jwst/source_catalog"
# root="../../../../jwst/source_catalog/__pycache__"
# root="../../../../jwst/srctype"
# root="../../../../jwst/srctype/__pycache__"
# root="../../../../jwst/stpipe"
# root="../../../../jwst/stpipe/__pycache__"
# root="../../../../jwst/stpipe/configobj"
# root="../../../../jwst/stpipe/configobj/__pycache__"
# root="../../../../jwst/stpipe/tests"
# 	****rejected
# root="../../../../jwst/stpipe/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/stpipe/tests/data"
# 	****rejected
# root="../../../../jwst/stpipe/tests/data/__pycache__"
# 	****rejected
# root="../../../../jwst/stpipe/tests/data/junk"
# 	****rejected
# root="../../../../jwst/stpipe/tests/notebooks"
# 	****rejected
# root="../../../../jwst/stpipe/tests/notebooks/.ipynb_checkpoints"
# 	****rejected
# root="../../../../jwst/stpipe/tests/steps"
# 	****rejected
# root="../../../../jwst/stpipe/tests/steps/__pycache__"
# 	****rejected
# root="../../../../jwst/straylight"
# root="../../../../jwst/straylight/__pycache__"
# root="../../../../jwst/superbias"
# root="../../../../jwst/superbias/__pycache__"
# root="../../../../jwst/tests"
# 	****rejected
# root="../../../../jwst/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/timeconversion"
# root="../../../../jwst/timeconversion/__pycache__"
# root="../../../../jwst/transforms"
# root="../../../../jwst/transforms/__pycache__"
# root="../../../../jwst/transforms/schemas"
# root="../../../../jwst/transforms/schemas/__pycache__"
# root="../../../../jwst/transforms/schemas/stsci.edu"
# root="../../../../jwst/transforms/schemas/stsci.edu/jwst_pipeline"
# root="../../../../jwst/transforms/tags"
# root="../../../../jwst/transforms/tags/__pycache__"
# root="../../../../jwst/transforms/tags/tests"
# 	****rejected
# root="../../../../jwst/transforms/tags/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/transforms/tests"
# 	****rejected
# root="../../../../jwst/transforms/tests/__pycache__"
# 	****rejected
# root="../../../../jwst/tso_photometry"
# root="../../../../jwst/tso_photometry/__pycache__"
# root="../../../../jwst/tweakreg"
# root="../../../../jwst/tweakreg/__pycache__"
# root="../../../../jwst/tweakreg_catalog"
# root="../../../../jwst/tweakreg_catalog/__pycache__"
# root="../../../../jwst/wfs_combine"
# root="../../../../jwst/wfs_combine/__pycache__"
# root="../../../../jwst/white_light"
# root="../../../../jwst/white_light/__pycache__"
# root="../../../../jwst/wiimatch"
# root="../../../../jwst/wiimatch/__pycache__"

# %%
step_klasses = set(
    klass
    for module in modules
    for klass_name, klass in getmembers(module, lambda o: isclass(o) and issubclass(o, Step))
)

# %%
step_klass_objs = []
for klass in step_klasses:
    try:
        klass_obj = klass()
    except Exception as exception:
        logging.warning('Cannot instantiate {}'.format(klass))
    else:
        step_klass_objs.append(klass_obj)
# Out:
# 2018-04-06 13:10:35,018 - stpipe.Extract1dStep - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,032 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-06 13:10:35,034 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-06 13:10:35,036 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:10:35,037 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-06 13:10:35,038 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-06 13:10:35,040 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-06 13:10:35,042 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,043 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-06 13:10:35,044 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-06 13:10:35,046 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-06 13:10:35,047 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-06 13:10:35,048 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-06 13:10:35,050 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,051 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:10:35,053 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:10:35,054 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,055 - stpipe.StackRefsStep - INFO - StackRefsStep instance created.
# 2018-04-06 13:10:35,057 - stpipe.TSOPhotometryStep - INFO - TSOPhotometryStep instance created.
# 2018-04-06 13:10:35,058 - stpipe.GuiderCdsStep - INFO - GuiderCdsStep instance created.
# 2018-04-06 13:10:35,059 - stpipe.KlipStep - INFO - KlipStep instance created.
# 2018-04-06 13:10:35,060 - stpipe.AmiAnalyzeStep - INFO - AmiAnalyzeStep instance created.
# 2018-04-06 13:10:35,061 - stpipe.ImprintStep - INFO - ImprintStep instance created.
# 2018-04-06 13:10:35,063 - stpipe.TweakRegStep - INFO - TweakRegStep instance created.
# 2018-04-06 13:10:35,065 - stpipe.OutlierDetectionStackStep - INFO - OutlierDetectionStackStep instance created.
# 2018-04-06 13:10:35,066 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2018-04-06 13:10:35,067 - stpipe.Combine1dStep - INFO - Combine1dStep instance created.
# 2018-04-06 13:10:35,069 - stpipe.MSAFlagOpenStep - INFO - MSAFlagOpenStep instance created.
# 2018-04-06 13:10:35,073 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,074 - stpipe.JumpStep - INFO - JumpStep instance created.
# 2018-04-06 13:10:35,076 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,078 - stpipe.WfsCombineStep - INFO - WfsCombineStep instance created.
# 2018-04-06 13:10:35,079 - stpipe.SubtractImagesStep - INFO - SubtractImagesStep instance created.
# 2018-04-06 13:10:35,081 - stpipe.CubeSkyMatchStep - INFO - CubeSkyMatchStep instance created.
# 2018-04-06 13:10:35,090 - stpipe.TestLinearPipeline - INFO - TestLinearPipeline instance created.
# 2018-04-06 13:10:35,092 - stpipe.TestLinearPipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,094 - stpipe.TestLinearPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,096 - stpipe.TestLinearPipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,097 - stpipe.TestLinearPipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,159 - stpipe.TestLinearPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:10:35,160 - stpipe.TestLinearPipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,162 - stpipe.TestLinearPipeline.jump - INFO - JumpStep instance created.
# 2018-04-06 13:10:35,163 - stpipe.TestLinearPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-06 13:10:35,164 - stpipe.TestLinearPipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-06 13:10:35,165 - stpipe.TestLinearPipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,166 - stpipe.TestLinearPipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:10:35,168 - stpipe.TestLinearPipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-06 13:10:35,169 - stpipe.TestLinearPipeline.fringe - INFO - FringeStep instance created.
# 2018-04-06 13:10:35,170 - stpipe.TestLinearPipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,174 - stpipe.Tso3Pipeline - INFO - Tso3Pipeline instance created.
# 2018-04-06 13:10:35,176 - stpipe.Tso3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,177 - stpipe.Tso3Pipeline.tso_photometry - INFO - TSOPhotometryStep instance created.
# 2018-04-06 13:10:35,179 - stpipe.Tso3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,180 - stpipe.Tso3Pipeline.white_light - INFO - WhiteLightStep instance created.
# 2018-04-06 13:10:35,181 - stpipe.GroupScaleStep - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,183 - stpipe.PathLossStep - INFO - PathLossStep instance created.
# 2018-04-06 13:10:35,184 - stpipe.ResampleStep - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,186 - stpipe.OutlierDetectionScaledStep - INFO - OutlierDetectionScaledStep instance created.
# 2018-04-06 13:10:35,190 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2018-04-06 13:10:35,191 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-06 13:10:35,193 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:10:35,194 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,195 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,197 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,198 - stpipe.SkyMatchStep - INFO - SkyMatchStep instance created.
# 2018-04-06 13:10:35,203 - stpipe.Ami3Pipeline - INFO - Ami3Pipeline instance created.
# 2018-04-06 13:10:35,204 - stpipe.Ami3Pipeline.ami_analyze - INFO - AmiAnalyzeStep instance created.
# 2018-04-06 13:10:35,205 - stpipe.Ami3Pipeline.ami_average - INFO - AmiAverageStep instance created.
# 2018-04-06 13:10:35,206 - stpipe.Ami3Pipeline.ami_normalize - INFO - AmiNormalizeStep instance created.
# 2018-04-06 13:10:35,209 - stpipe.GuiderPipeline - INFO - GuiderPipeline instance created.
# 2018-04-06 13:10:35,210 - stpipe.GuiderPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,212 - stpipe.GuiderPipeline.guider_cds - INFO - GuiderCdsStep instance created.
# 2018-04-06 13:10:35,213 - stpipe.GuiderPipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,214 - stpipe.MRSIMatchStep - INFO - MRSIMatchStep instance created.
# 2018-04-06 13:10:35,219 - stpipe.DarkPipeline - INFO - DarkPipeline instance created.
# 2018-04-06 13:10:35,220 - stpipe.DarkPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,222 - stpipe.DarkPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,223 - stpipe.DarkPipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,225 - stpipe.DarkPipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,227 - stpipe.DarkPipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,228 - stpipe.DarkPipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,229 - stpipe.DarkPipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,230 - stpipe.DarkPipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,231 - stpipe.DarkPipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,232 - stpipe - WARNING - Cannot instantiate <class 'jwst.stpipe.function_wrapper.FunctionWrapper'>
# 2018-04-06 13:10:35,233 - stpipe.Step - INFO - Step instance created.
# 2018-04-06 13:10:35,234 - stpipe.AmiAverageStep - INFO - AmiAverageStep instance created.
# 2018-04-06 13:10:35,235 - stpipe.AmiNormalizeStep - INFO - AmiNormalizeStep instance created.
# 2018-04-06 13:10:35,236 - stpipe.RefPixStep - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,242 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2018-04-06 13:10:35,243 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2018-04-06 13:10:35,245 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,247 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:10:35,249 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:10:35,252 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,253 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2018-04-06 13:10:35,254 - stpipe.SourceCatalogStep - INFO - SourceCatalogStep instance created.
# 2018-04-06 13:10:35,256 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2018-04-06 13:10:35,257 - stpipe.AlignRefsStep - INFO - AlignRefsStep instance created.
# 2018-04-06 13:10:35,259 - stpipe.StraylightStep - INFO - StraylightStep instance created.
# 2018-04-06 13:10:35,260 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:10:35,261 - stpipe.ResampleSpecStep - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:10:35,263 - stpipe.PersistenceStep - INFO - PersistenceStep instance created.
# 2018-04-06 13:10:35,264 - stpipe.FringeStep - INFO - FringeStep instance created.
# 2018-04-06 13:10:35,265 - stpipe.Extract2dStep - INFO - Extract2dStep instance created.
# 2018-04-06 13:10:35,266 - stpipe - WARNING - Cannot instantiate <class 'jwst.stpipe.subproc.SystemCall'>
# 2018-04-06 13:10:35,268 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,269 - stpipe.HlspStep - INFO - HlspStep instance created.
# 2018-04-06 13:10:35,271 - stpipe.Pipeline - INFO - Pipeline instance created.
# 2018-04-06 13:10:35,273 - stpipe.BarShadowStep - INFO - BarShadowStep instance created.
# 2018-04-06 13:10:35,275 - stpipe.IPCStep - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,276 - stpipe.FirstFrameStep - INFO - FirstFrameStep instance created.
# 2018-04-06 13:10:35,277 - stpipe.FlatFieldStep - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,279 - stpipe.BackgroundStep - INFO - BackgroundStep instance created.
# 2018-04-06 13:10:35,280 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,282 - stpipe.PhotomStep - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,283 - stpipe.SourceTypeStep - INFO - SourceTypeStep instance created.
# 2018-04-06 13:10:35,284 - stpipe.EngDBLogStep - INFO - EngDBLogStep instance created.
# 2018-04-06 13:10:35,285 - stpipe.LastFrameStep - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,289 - stpipe.Coron3Pipeline - INFO - Coron3Pipeline instance created.
# 2018-04-06 13:10:35,291 - stpipe.Coron3Pipeline.stack_refs - INFO - StackRefsStep instance created.
# 2018-04-06 13:10:35,292 - stpipe.Coron3Pipeline.align_refs - INFO - AlignRefsStep instance created.
# 2018-04-06 13:10:35,294 - stpipe.Coron3Pipeline.klip - INFO - KlipStep instance created.
# 2018-04-06 13:10:35,297 - stpipe.Coron3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,298 - stpipe.Coron3Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,300 - stpipe.ResetStep - INFO - ResetStep instance created.
# 2018-04-06 13:10:35,301 - stpipe.WhiteLightStep - INFO - WhiteLightStep instance created.
# 2018-04-06 13:10:35,302 - stpipe.LinearPipeline - INFO - LinearPipeline instance created.
# 2018-04-06 13:10:35,304 - stpipe.OutlierDetectionStep - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,313 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-06 13:10:35,314 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,316 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,317 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,318 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,320 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,321 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,322 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,324 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:10:35,325 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,326 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,328 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:10:35,329 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:10:35,330 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-06 13:10:35,331 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-06 13:10:35,333 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:10:35,334 - stpipe.EmissionStep - INFO - EmissionStep instance created.
# 2018-04-06 13:10:35,340 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2018-04-06 13:10:35,342 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2018-04-06 13:10:35,345 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2018-04-06 13:10:35,346 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,348 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,349 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2018-04-06 13:10:35,350 - stpipe.RSCD_Step - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,351 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.

# %%
for step_klass_obj in step_klass_objs:
    try:
        name = step_klass_obj.name
    except Exception as exception:
        pass
    else:
        suffixes.add(name.lower())

# %%
len(suffixes)
# Out:
# 69

# %% [markdown]
# ## Instantiate from config files
# `Step` and `Pipeline` can be instantiated from config files. These can define different names and suffixes. Collect what we can.
#
# _Note_: Based on `collect_cfgs` script where configuration files are only searched for in the `pipeline` module.

# %%
config_path = path.join(package_location, 'pipeline')

# %%
for config_file in listdir(config_path):
    if config_file.endswith('.cfg'):
        try:
            step = Step.from_config_file(path.join(config_path, config_file))
        except Exception as exception:
            logging.warning('Could not instantiate {}'.format(config_file))
        else:
            suffixes.add(step.name.lower())
            if step.suffix is not None:
                suffixes.add(step.suffix.lower())
# Out:
# 2018-04-06 13:10:35,560 - stpipe.alignrefs - INFO - AlignRefsStep instance created.
# 2018-04-06 13:10:35,562 - stpipe.ami_analyze - INFO - AmiAnalyzeStep instance created.
# 2018-04-06 13:10:35,564 - stpipe.ami_average - INFO - AmiAverageStep instance created.
# 2018-04-06 13:10:35,566 - stpipe.ami_normalize - INFO - AmiNormalizeStep instance created.
# 2018-04-06 13:10:35,567 - stpipe.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:10:35,570 - stpipe.background - INFO - BackgroundStep instance created.
# 2018-04-06 13:10:35,576 - stpipe.Ami3Pipeline - INFO - Ami3Pipeline instance created.
# 2018-04-06 13:10:35,577 - stpipe.Ami3Pipeline.ami_analyze - INFO - AmiAnalyzeStep instance created.
# 2018-04-06 13:10:35,578 - stpipe.Ami3Pipeline.ami_average - INFO - AmiAverageStep instance created.
# 2018-04-06 13:10:35,579 - stpipe.Ami3Pipeline.ami_normalize - INFO - AmiNormalizeStep instance created.
# 2018-04-06 13:10:35,584 - stpipe.Coron3Pipeline - INFO - Coron3Pipeline instance created.
# 2018-04-06 13:10:35,585 - stpipe.Coron3Pipeline.stack_refs - INFO - StackRefsStep instance created.
# 2018-04-06 13:10:35,586 - stpipe.Coron3Pipeline.align_refs - INFO - AlignRefsStep instance created.
# 2018-04-06 13:10:35,587 - stpipe.Coron3Pipeline.klip - INFO - KlipStep instance created.
# 2018-04-06 13:10:35,589 - stpipe.Coron3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,590 - stpipe.Coron3Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,600 - stpipe.DarkPipeline - INFO - DarkPipeline instance created.
# 2018-04-06 13:10:35,602 - stpipe.DarkPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,604 - stpipe.DarkPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,605 - stpipe.DarkPipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,607 - stpipe.DarkPipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,608 - stpipe.DarkPipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,609 - stpipe.DarkPipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,610 - stpipe.DarkPipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,612 - stpipe.DarkPipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,613 - stpipe.DarkPipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,627 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-06 13:10:35,628 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,629 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,630 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,632 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,633 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,635 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,636 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,638 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:10:35,639 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,640 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,641 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:10:35,642 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:10:35,644 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-06 13:10:35,645 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-06 13:10:35,646 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:10:35,649 - stpipe.GuiderPipeline - INFO - GuiderPipeline instance created.
# 2018-04-06 13:10:35,651 - stpipe.GuiderPipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,652 - stpipe.GuiderPipeline.guider_cds - INFO - GuiderCdsStep instance created.
# 2018-04-06 13:10:35,654 - stpipe.GuiderPipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,662 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2018-04-06 13:10:35,663 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-06 13:10:35,664 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:10:35,666 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,667 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,668 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,682 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2018-04-06 13:10:35,684 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2018-04-06 13:10:35,686 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2018-04-06 13:10:35,688 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,689 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,691 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2018-04-06 13:10:35,702 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-06 13:10:35,703 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-06 13:10:35,705 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-06 13:10:35,706 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-06 13:10:35,708 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-06 13:10:35,709 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-06 13:10:35,710 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,712 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-06 13:10:35,713 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-06 13:10:35,714 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-06 13:10:35,715 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-06 13:10:35,716 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-06 13:10:35,718 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,719 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:10:35,722 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:10:35,723 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,729 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2018-04-06 13:10:35,731 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2018-04-06 13:10:35,732 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,734 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:10:35,736 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:10:35,737 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,748 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-06 13:10:35,749 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,750 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,751 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,752 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,753 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,755 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,756 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,758 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:10:35,759 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,760 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,762 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:10:35,763 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:10:35,765 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-06 13:10:35,767 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-06 13:10:35,768 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:10:35,777 - stpipe.Tso3Pipeline - INFO - Tso3Pipeline instance created.
# 2018-04-06 13:10:35,779 - stpipe.Tso3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,781 - stpipe.Tso3Pipeline.tso_photometry - INFO - TSOPhotometryStep instance created.
# 2018-04-06 13:10:35,782 - stpipe.Tso3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,783 - stpipe.Tso3Pipeline.white_light - INFO - WhiteLightStep instance created.
# 2018-04-06 13:10:35,786 - stpipe.combine_1d - INFO - Combine1dStep instance created.
# 2018-04-06 13:10:35,788 - stpipe.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-06 13:10:35,791 - stpipe.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-06 13:10:35,795 - stpipe.dq_init - INFO - DQInitStep instance created.
# 2018-04-06 13:10:35,798 - stpipe.emission - INFO - EmissionStep instance created.
# 2018-04-06 13:10:35,800 - stpipe.engdblog - INFO - EngDBLogStep instance created.
# 2018-04-06 13:10:35,801 - stpipe.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-06 13:10:35,803 - stpipe.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-06 13:10:35,804 - stpipe.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-06 13:10:35,806 - stpipe.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-06 13:10:35,810 - stpipe.fringe - INFO - FringeStep instance created.
# 2018-04-06 13:10:35,813 - stpipe.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-06 13:10:35,815 - stpipe.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-06 13:10:35,817 - stpipe.GuiderCDS - INFO - GuiderCdsStep instance created.
# 2018-04-06 13:10:35,819 - stpipe.hlsp - INFO - HlspStep instance created.
# 2018-04-06 13:10:35,821 - stpipe.imprint - INFO - ImprintStep instance created.
# 2018-04-06 13:10:35,823 - stpipe.ipc - INFO - IPCStep instance created.
# 2018-04-06 13:10:35,826 - stpipe.jump - INFO - JumpStep instance created.
# 2018-04-06 13:10:35,828 - stpipe.klip - INFO - KlipStep instance created.
# 2018-04-06 13:10:35,830 - stpipe.lastframe - INFO - LastFrameStep instance created.
# 2018-04-06 13:10:35,841 - stpipe - WARNING - Could not instantiate linear_pipeline.cfg
# 2018-04-06 13:10:35,843 - stpipe.linearity - INFO - LinearityStep instance created.
# 2018-04-06 13:10:35,845 - stpipe.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2018-04-06 13:10:35,848 - stpipe.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,851 - stpipe.outlier_detection_scaled - INFO - OutlierDetectionScaledStep instance created.
# 2018-04-06 13:10:35,853 - stpipe - WARNING - Could not instantiate outlier_detection_stack.cfg
# 2018-04-06 13:10:35,855 - stpipe.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-04-06 13:10:35,859 - stpipe.pathloss - INFO - PathLossStep instance created.
# 2018-04-06 13:10:35,861 - stpipe.persistence - INFO - PersistenceStep instance created.
# 2018-04-06 13:10:35,863 - stpipe.photom - INFO - PhotomStep instance created.
# 2018-04-06 13:10:35,866 - stpipe.RampFit - INFO - RampFitStep instance created.
# 2018-04-06 13:10:35,867 - stpipe.refpix - INFO - RefPixStep instance created.
# 2018-04-06 13:10:35,870 - stpipe.resample - INFO - ResampleStep instance created.
# 2018-04-06 13:10:35,873 - stpipe.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-06 13:10:35,876 - stpipe.reset - INFO - ResetStep instance created.
# 2018-04-06 13:10:35,878 - stpipe.rscd - INFO - RSCD_Step instance created.
# 2018-04-06 13:10:35,880 - stpipe.saturation - INFO - SaturationStep instance created.
# 2018-04-06 13:10:35,882 - stpipe.skymatch - INFO - SkyMatchStep instance created.
# 2018-04-06 13:10:35,884 - stpipe.source_catalog - INFO - SourceCatalogStep instance created.
# 2018-04-06 13:10:35,886 - stpipe.srctype - INFO - SourceTypeStep instance created.
# 2018-04-06 13:10:35,889 - stpipe.stackrefs - INFO - StackRefsStep instance created.
# 2018-04-06 13:10:35,891 - stpipe.straylight - INFO - StraylightStep instance created.
# 2018-04-06 13:10:35,893 - stpipe.subtract_images - INFO - SubtractImagesStep instance created.
# 2018-04-06 13:10:35,895 - stpipe.superbias - INFO - SuperBiasStep instance created.
# 2018-04-06 13:10:35,897 - stpipe.tweakreg - INFO - TweakRegStep instance created.
# 2018-04-06 13:10:35,899 - stpipe.WfsCombine - INFO - WfsCombineStep instance created.
# 2018-04-06 13:10:35,901 - stpipe.white_light - INFO - WhiteLightStep instance created.

# %%
len(suffixes)
# Out:
# 122

# %%
suffixes_from_find.symmetric_difference(suffixes)
# Out:
# {'functionwrapper', 'systemcall'}

# %%
suffixes
# Out:
# {'alignrefs',
#  'alignrefsstep',
#  'ami3pipeline',
#  'ami_analyze',
#  'ami_average',
#  'ami_normalize',
#  'amianalyzestep',
#  'amiaveragestep',
#  'aminormalizestep',
#  'assign_wcs',
#  'assignwcsstep',
#  'background',
#  'backgroundstep',
#  'barshadowstep',
#  'combine1dstep',
#  'combine_1d',
#  'coron3pipeline',
#  'cube_build',
#  'cubebuildstep',
#  'cubeskymatchstep',
#  'dark',
#  'dark_current',
#  'darkcurrentstep',
#  'darkpipeline',
#  'detector1pipeline',
#  'dq_init',
#  'dqinitstep',
#  'emission',
#  'emissionstep',
#  'engdblog',
#  'engdblogstep',
#  'extract1dstep',
#  'extract2dstep',
#  'extract_1d',
#  'extract_2d',
#  'firstframe',
#  'firstframestep',
#  'flat_field',
#  'flatfieldstep',
#  'fringe',
#  'fringestep',
#  'gain_scale',
#  'gainscalestep',
#  'group_scale',
#  'groupscalestep',
#  'guidercds',
#  'guidercdsstep',
#  'guiderpipeline',
#  'hlsp',
#  'hlspstep',
#  'i2d',
#  'image2pipeline',
#  'image3pipeline',
#  'imprint',
#  'imprintstep',
#  'ipc',
#  'ipcstep',
#  'jump',
#  'jumpstep',
#  'klip',
#  'klipstep',
#  'lastframe',
#  'lastframestep',
#  'linearity',
#  'linearitystep',
#  'linearpipeline',
#  'mrs_imatch',
#  'mrsimatchstep',
#  'msaflagopenstep',
#  'outlier_detection',
#  'outlier_detection_scaled',
#  'outlierdetectionscaledstep',
#  'outlierdetectionstackstep',
#  'outlierdetectionstep',
#  'pathloss',
#  'pathlossstep',
#  'persistence',
#  'persistencestep',
#  'photom',
#  'photomstep',
#  'pipeline',
#  'rampfit',
#  'rampfitstep',
#  'refpix',
#  'refpixstep',
#  'resample',
#  'resample_spec',
#  'resamplespecstep',
#  'resamplestep',
#  'reset',
#  'resetstep',
#  'rscd',
#  'rscd_step',
#  's2d',
#  'saturation',
#  'saturationstep',
#  'skymatch',
#  'skymatchstep',
#  'source_catalog',
#  'sourcecatalogstep',
#  'sourcetypestep',
#  'spec2pipeline',
#  'spec3pipeline',
#  'srctype',
#  'stackrefs',
#  'stackrefsstep',
#  'step',
#  'straylight',
#  'straylightstep',
#  'subtract_images',
#  'subtractimagesstep',
#  'superbias',
#  'superbiasstep',
#  'testlinearpipeline',
#  'tso3pipeline',
#  'tsophotometrystep',
#  'tweakreg',
#  'tweakregstep',
#  'wfscombine',
#  'wfscombinestep',
#  'white_light',
#  'whitelightstep'}
